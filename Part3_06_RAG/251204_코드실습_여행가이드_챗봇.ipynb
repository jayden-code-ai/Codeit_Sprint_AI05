# %% [markdown]
# # 여행가이드 챗봇

# %% [markdown]
# ## RAG 실습 준비

# %%
# !pip install langchain_community langchain_text_splitters langchain_openai langchain_chroma
# Out:
# Requirement already satisfied: langchain_community in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: langchain_text_splitters in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: langchain_openai in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: langchain_chroma in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (1.1.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (2.0.44)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (0.4.53)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.12.0)
# Requirement already satisfied: zstandard>=0.23.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: anyio in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.11.0)
# Requirement already satisfied: certifi in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.3.0)
# Requirement already satisfied: greenlet>=1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_openai) (2.8.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (0.12.0)
# Requirement already satisfied: sniffio in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2025.11.3)
# Requirement already satisfied: chromadb<2.0.0,>=1.0.20 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_chroma) (1.3.5)
# Requirement already satisfied: build>=1.0.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.38.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.39.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.39.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.39.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (4.25.1)
# Requirement already satisfied: six>=1.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.2.1)
# Requirement already satisfied: pyproject_hooks in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.29.0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.6.1)
# Requirement already satisfied: coloredlogs in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (25.9.23)
# Requirement already satisfied: protobuf in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (6.33.1)
# Requirement already satisfied: sympy in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.39.0)
# Requirement already satisfied: opentelemetry-proto==1.39.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.39.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.60b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.36.0)
# Requirement already satisfied: filelock in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain_chroma) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.2.0)
# Requirement already satisfied: click>=8.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.3.0)

# %%
import os

from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_chroma import Chroma
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

# %%
# 0. 초기설정
import os
from getpass import getpass

# OpenAI API 키 입력
openai_api_key = getpass('Enter your OpenAI API key: ')

# OpenAI API 키 저장
os.environ['OPENAI_API_KEY'] = openai_api_key

# %%
# 가상 데이터 생성(여행가이드 문서)
jeju_content = """
[제주도 맛집 & 여행 가이드]
1. 흑돼지 거리: 제주시 건입동에 위치. 저녁 7시 이후에는 웨이팅이 1시간 이상 발생할 수 있음. 
   추천 메뉴는 흑돼지 오겹살(200g 2만원). 멜젓에 찍어 먹는 것이 특징.
   
2. 우도 땅콩 아이스크림: 우도 검멀레 해변 앞이 원조. 가격은 5,000원. 
   고소한 땅콩 가루가 듬뿍 뿌려져 있음. 배 시간 때문에 오후 4시 이전에 가는 것을 추천.
   
3. 성산일출봉: 입장료 5,000원. 왕복 소요 시간 50분. 
   매월 첫째 주 월요일은 휴관. 새벽 일출을 보려면 전날 근처 숙소 예약 필수.
"""

# 파일 저장
with open("jeju_guide.txt", "w", encoding="utf-8") as f:
    f.write(jeju_content)

print("[준비완료] 여행 가이드 문서가 생성되었습니다.")
# Out:
# [준비완료] 여행 가이드 문서가 생성되었습니다.

# %% [markdown]
# ## RAG 실습 시작 - LangChain 사용
#
# ### 문서 로딩

# %%
# 1. 문서 로딩
print("\n 문서를 불러옵니다...")
loader = TextLoader("jeju_guide.txt", encoding="utf-8")
docs = loader.load()
print(f"   -> {len(docs[0].page_content)}자")
# Out:
#  문서를 불러옵니다...
#    -> 315자

# %%
# 2. 문서 분할
print("\n 문서를 작은 조각(Chunk)으로 나눕니다...")
text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20)
splits = text_splitter.split_documents(docs)
print(f"\n 총 {len(splits)}개의 조각(Chunk)로 분할되었습니다.")
# Out:
#  문서를 작은 조각(Chunk)으로 나눕니다...
#
#  총 4개의 조각(Chunk)로 분할되었습니다.

# %%
# 3. 임베딩 & 벡터 저장소 생성
print("\n 문서를 벡터로 변환하여 저장합니다...")
vectorstore = Chroma.from_documents(
    documents=splits,
    embedding=OpenAIEmbeddings(model="text-embedding-3-small")
)

print("   -> Chroma DB에 저장완료!")
# Out:
#  문서를 벡터로 변환하여 저장합니다...
#    -> Chroma DB에 저장완료!

# %%
# 4. Retriever 설정 & Generation
print("\n RAG 체인을 생성합니다...")

retriever = vectorstore.as_retriever(search_kwargs={"k": 3})

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
# Out:
#  RAG 체인을 생성합니다...

# %%
# 프롬프트 템플릿 작성
template = """
당신은 제주도 여행 가이드 담당자압니다.
아래 [가이드]를 참고하여 여행자의 질문에 친절하게 답해주세요.
가이드에 없는 내용은 별로의 검색엔진을 이용하도록 안내해 주세요.

[가이드]:
{context}

[질문]:
{question}
"""
prompt = PromptTemplate.from_template(template)

# %%
# 체인 연결
rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %%
# 5. 실행
question = "흑돼지 먹으려면 어디로 가야 해? 그리고 성산일출봉 입장료는 얼마야?"

print(f"\n 질문: {question}")
print("AI 답변 생성중...\n")

response = rag_chain.invoke(question)

print(response)
# Out:
#  질문: 흑돼지 먹으려면 어디로 가야 해? 그리고 성산일출봉 입장료는 얼마야?
# AI 답변 생성중...
#
# 흑돼지를 드시려면 제주시 건입동에 위치한 흑돼지 거리를 추천합니다. 저녁 7시 이후에는 웨이팅이 1시간 이상 발생할 수 있으니, 미리 가시는 것이 좋습니다.
#
# 성산일출봉의 입장료는 5,000원입니다. 왕복 소요 시간은 약 50분 정도 걸립니다. 즐거운 여행 되세요!

# %%
# 5. 실행
question = "성산일출봉을 편도로 가면 시간이 얼마나 걸릴까?"

print(f"\n 질문: {question}")
print("AI 답변 생성중...\n")

response = rag_chain.invoke(question)

print(response)
# Out:
#  질문: 성산일출봉을 편도로 가면 시간이 얼마나 걸릴까?
# AI 답변 생성중...
#
# 성산일출봉은 왕복 소요 시간이 약 50분입니다. 편도로 가는 경우에는 대략 25분 정도 걸릴 것으로 예상됩니다. 즐거운 여행 되세요!

# %%
# 5. 실행
question = "흑돼지 2인분과 우동 땅콩아이스트림 2개를 먹었는데 합계 금액은 얼마야?"

print(f"\n 질문: {question}")
print("AI 답변 생성중...\n")

response = rag_chain.invoke(question)

print(response)
# Out:
#  질문: 흑돼지 2인분과 우동 땅콩아이스트림 2개를 먹었는데 합계 금액은 얼마야?
# AI 답변 생성중...
#
# 흑돼지 오겹살 2인분(200g 기준, 1인분 2만원)과 우도 땅콩 아이스크림 2개(가격 5,000원)로 계산해보면:
#
# - 흑돼지 오겹살 2인분: 2만원 x 2 = 4만원
# - 우도 땅콩 아이스크림 2개: 5,000원 x 2 = 1만원
#
# 따라서, 총 합계 금액은 4만원 + 1만원 = 5만원입니다. 맛있게 드세요!
