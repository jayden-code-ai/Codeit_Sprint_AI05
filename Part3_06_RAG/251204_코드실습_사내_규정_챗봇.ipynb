# %% [markdown]
# # 사내 규정 챗봇 만들기

# %% [markdown]
# ## RAG 실습 준비

# %%
# !pip install langchain_community langchain_text_splitters langchain_openai langchain_chroma
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain_text_splitters
#   Downloading langchain_text_splitters-1.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain_openai in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (1.1.0)
# Collecting langchain_chroma
#   Downloading langchain_chroma-1.0.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (1.1.0)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain_community)
#   Downloading langchain_classic-1.0.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain_community)
#   Downloading sqlalchemy-2.0.44-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (9.1.2)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain_community)
#   Downloading pydantic_settings-2.12.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (0.4.53)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.26.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.12.0)
# Requirement already satisfied: zstandard>=0.23.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: anyio in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.11.0)
# Requirement already satisfied: certifi in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.5.0)
# Collecting greenlet>=1 (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community)
#   Downloading greenlet-3.2.4-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_openai) (2.8.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (0.12.0)
# Requirement already satisfied: sniffio in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2025.11.3)
# Collecting chromadb<2.0.0,>=1.0.20 (from langchain_chroma)
#   Downloading chromadb-1.3.5-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.2 kB)
# Collecting build>=1.0.3 (from chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading build-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pybase64>=1.4.1 (from chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading pybase64-1.4.2-cp310-cp310-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (8.7 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading onnxruntime-1.23.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading opentelemetry_api-1.39.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.39.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading opentelemetry_sdk-1.39.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.22.1)
# Collecting pypika>=0.48.9 (from chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting overrides>=7.3.1 (from chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting grpcio>=1.58.0 (from chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading grpcio-1.76.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.7 kB)
# Collecting bcrypt>=4.0.1 (from chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading typer-0.20.0-py3-none-any.whl.metadata (16 kB)
# Collecting kubernetes>=28.1.0 (from chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading kubernetes-34.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting mmh3>=4.0.1 (from chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading mmh3-5.2.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (14 kB)
# Collecting rich>=10.11.0 (from chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Using cached rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (4.25.1)
# Requirement already satisfied: six>=1.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.9.0.post0)
# Collecting backoff>=1.10.0 (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting tomli>=1.1.0 (from build>=1.0.3->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Using cached tomli-2.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.29.0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading google_auth-2.43.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Using cached websocket_client-1.9.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.32.5->langchain_community)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting cachetools<7.0,>=2.0.0 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading cachetools-6.2.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading protobuf-6.33.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: sympy in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.14.0)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.39.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.39.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.39.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading opentelemetry_proto-1.39.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.60b0 (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading opentelemetry_semantic_conventions-0.60b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.36.0)
# Requirement already satisfied: filelock in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain_chroma) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.2.0)
# Requirement already satisfied: click>=8.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (8.3.1)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading httptools-0.7.1-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (3.5 kB)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading uvloop-0.22.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading watchfiles-1.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading websockets-15.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.3.0)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 50.2 MB/s  0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 37.0 MB/s  0:00:00
# Downloading langchain_text_splitters-1.0.0-py3-none-any.whl (33 kB)
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading pydantic_settings-2.12.0-py3-none-any.whl (51 kB)
# Downloading sqlalchemy-2.0.44-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 52.3 MB/s  0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading langchain_chroma-1.0.0-py3-none-any.whl (12 kB)
# Downloading chromadb-1.3.5-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 51.4 MB/s  0:00:00m0:00:0100:01
# Downloading posthog-5.4.0-py3-none-any.whl (105 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (278 kB)
# Downloading build-1.3.0-py3-none-any.whl (23 kB)
# Downloading greenlet-3.2.4-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (584 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.4/584.4 kB 35.2 MB/s  0:00:00
# Downloading grpcio-1.76.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 48.9 MB/s  0:00:00
# Downloading kubernetes-34.1.0-py2.py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 47.3 MB/s  0:00:00
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
# Downloading cachetools-6.2.2-py3-none-any.whl (11 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading mmh3-5.2.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (101 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading onnxruntime-1.23.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 54.1 MB/s  0:00:00 eta 0:00:01
# Downloading opentelemetry_api-1.39.0-py3-none-any.whl (66 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.39.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.39.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.39.0-py3-none-any.whl (72 kB)
# Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Downloading opentelemetry_sdk-1.39.0-py3-none-any.whl (132 kB)
# Downloading opentelemetry_semantic_conventions-0.60b0-py3-none-any.whl (219 kB)
# Downloading protobuf-6.33.1-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pybase64-1.4.2-cp310-cp310-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (68 kB)
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached tomli-2.3.0-py3-none-any.whl (14 kB)
# Downloading typer-0.20.0-py3-none-any.whl (47 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Downloading httptools-0.7.1-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (440 kB)
# Downloading uvloop-0.22.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 50.9 MB/s  0:00:00
# Downloading watchfiles-1.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (455 kB)
# Using cached websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Downloading websockets-15.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (181 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53803 sha256=f0e6e7dd5d6053011bb69769c0e601a02cfff714b70b629cc0481760785ebbfc
#   Stored in directory: /home/jayden86/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, flatbuffers, durationpy, zipp, websockets, websocket-client, uvloop, uvicorn, urllib3, tomli, shellingham, pyproject_hooks, pybase64, pyasn1, protobuf, overrides, oauthlib, mypy-extensions, mmh3, mdurl, marshmallow, importlib-resources, humanfriendly, httpx-sse, httptools, grpcio, greenlet, cachetools, bcrypt, backoff, async-timeout, typing-inspect, SQLAlchemy, rsa, pyasn1-modules, opentelemetry-proto, markdown-it-py, importlib-metadata, googleapis-common-protos, coloredlogs, build, watchfiles, rich, requests-oauthlib, pydantic-settings, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnxruntime, google-auth, dataclasses-json, typer, opentelemetry-semantic-conventions, kubernetes, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, langchain_text_splitters, langchain-classic, chromadb, langchain_community, langchain_chroma
#   Attempting uninstall: urllib3━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/61 [uvloop]
#     Found existing installation: urllib3 2.5.0━━━━━━━━━━━━━━━━  6/61 [uvloop]
#     Uninstalling urllib3-2.5.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/61 [uvloop]
#       Successfully uninstalled urllib3-2.5.0━━━━━━━━━━━━━━━━━━  6/61 [uvloop]
#   Attempting uninstall: async-timeout━━━━━━━━━━━━━━━━━━━━━━━━ 24/61 [httptools]
#     Found existing installation: async-timeout 5.0.1━━━━━━━━━━ 24/61 [httptools]
#     Uninstalling async-timeout-5.0.1:m━━━━━━━━━━━━━━━━━━━━━━━━ 24/61 [httptools]
#       Successfully uninstalled async-timeout-5.0.1━━━━━━━━━━━━ 24/61 [httptools]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61/61 [langchain_chroma]n_chroma]n_community]ventions]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# trl 0.25.1 requires datasets>=3.0.0, but you have datasets 2.21.0 which is incompatible.
# Successfully installed SQLAlchemy-2.0.44 async-timeout-4.0.3 backoff-2.2.1 bcrypt-5.0.0 build-1.3.0 cachetools-6.2.2 chromadb-1.3.5 coloredlogs-15.0.1 dataclasses-json-0.6.7 durationpy-0.10 flatbuffers-25.9.23 google-auth-2.43.0 googleapis-common-protos-1.72.0 greenlet-3.2.4 grpcio-1.76.0 httptools-0.7.1 httpx-sse-0.4.3 humanfriendly-10.0 importlib-metadata-8.7.0 importlib-resources-6.5.2 kubernetes-34.1.0 langchain-classic-1.0.0 langchain_chroma-1.0.0 langchain_community-0.4.1 langchain_text_splitters-1.0.0 markdown-it-py-4.0.0 marshmallow-3.26.1 mdurl-0.1.2 mmh3-5.2.0 mypy-extensions-1.1.0 oauthlib-3.3.1 onnxruntime-1.23.2 opentelemetry-api-1.39.0 opentelemetry-exporter-otlp-proto-common-1.39.0 opentelemetry-exporter-otlp-proto-grpc-1.39.0 opentelemetry-proto-1.39.0 opentelemetry-sdk-1.39.0 opentelemetry-semantic-conventions-0.60b0 overrides-7.7.0 posthog-5.4.0 protobuf-6.33.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 pybase64-1.4.2 pydantic-settings-2.12.0 pypika-0.48.9 pyproject_hooks-1.2.0 requests-oauthlib-2.0.0 rich-14.2.0 rsa-4.9.1 shellingham-1.5.4 tomli-2.3.0 typer-0.20.0 typing-inspect-0.9.0 urllib3-2.3.0 uvicorn-0.38.0 uvloop-0.22.1 watchfiles-1.1.1 websocket-client-1.9.0 websockets-15.0.1 zipp-3.23.0

# %%
import os

from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_chroma import Chroma
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

# %%
# ==========================================
# 0. 초기 설정
# ==========================================
import os
from getpass import getpass

# OpenAI API key
openai_api_key = getpass("Enter your OpenAI API key: ")

# API키 설정
os.environ["OPENAI_API_KEY"] = openai_api_key

# %%
# 실습용 가상 데이터 생성 (사내 규정 문서)
# 실제로는 PDF나 txt 파일이 있는 경우가 많지만, 실습 편의를 위해 즉석에서 파일을 만듭니다.
policy_content = """
[주식회사 랭체인 인사 규정]
제1조 (근무 시간)
1. 근무 시간은 오전 9시부터 오후 6시까지로 한다.
2. 유연 근무제를 시행하며, 코어 타임(오전 11시~오후 3시)을 준수해야 한다.

제2조 (휴가)
1. 연차 휴가는 입사 1년 후 15일이 발생한다.
2. 3년 이상 근속 시 안식월 1개월을 유급으로 제공한다.
3. 반차, 반반차 사용이 가능하며 당일 신청도 가능하다.
4. 여름 휴가는 7월~8월 중 5일을 별도로 제공한다.

제3조 (복지)
1. 도서 구입비는 월 10만원 한도 내에서 무제한 지원한다.
2. 야근 시 택시비와 식대는 법인 카드로 결제한다.
"""

# 파일을 저장합니다.
with open("company_policy.txt", "w", encoding="utf-8") as f:
    f.write(policy_content)

print("[준비 완료] 사내 규정 문서가 생성되었습니다.")
# Out:
# [준비 완료] 사내 규정 문서가 생성되었습니다.

# %% [markdown]
# ## RAG 실습 시작 - LangChain 사용
#
# ### 문서 로딩

# %%
# ==========================================
# 1. 문서 로딩 (Loading)
# ==========================================
print("\n 문서를 불러옵니다...")
loader = TextLoader("company_policy.txt", encoding="utf-8")
docs = loader.load()
print(f"   -> 문서 길이: {len(docs[0].page_content)}자")
# Out:
#  문서를 불러옵니다...
#    -> 문서 길이: 321자

# %% [markdown]
# ### 문서 분할

# %%
# ==========================================
# 2. 문서 분할 (Splitting)
# ==========================================
print("\n 문서를 작은 조각(Chunk)으로 나눕니다...")
# chunk_size=100: 100자 단위로 자름
# chunk_overlap=20: 문맥이 끊기지 않도록 20자는 겹치게 함
text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20)
splits = text_splitter.split_documents(docs)
print(f"   -> 총 {len(splits)}개의 조각(Chunk)으로 분할되었습니다.")
# Out:
#  문서를 작은 조각(Chunk)으로 나눕니다...
#    -> 총 5개의 조각(Chunk)으로 분할되었습니다.

# %% [markdown]
# ### 임베딩 && 백터 저장소 생성

# %%
# ==========================================
# 3. 임베딩 & 벡터 저장소 생성 (Indexing)
# ==========================================
print("\n 문서를 벡터로 변환하여 저장합니다...")
# OpenAI의 가성비 임베딩 모델 사용
vectorstore = Chroma.from_documents(
    documents=splits,
    embedding=OpenAIEmbeddings(model="text-embedding-3-small")
)
print("   -> Chroma DB에 저장 완료!")
# Out:
#  문서를 벡터로 변환하여 저장합니다...
#    -> Chroma DB에 저장 완료!

# %% [markdown]
# ### 검색기(Retriever) 설정 & 생성(Generation)

# %%
# ==========================================
# 4. 검색기(Retriever) 설정 & 생성 (Generation)
# ==========================================
print("\n RAG 체인을 생성합니다...")

# 검색기 설정 (가장 유사한 문서 3개를 뽑아오도록 설정)
retriever = vectorstore.as_retriever(search_kwargs={"k": 3})

# LLM 모델 설정
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
# Out:
#  RAG 체인을 생성합니다...

# %%
# 프롬프트 템플릿 작성
# {context}: 검색된 문서 내용이 들어갈 자리
# {question}: 사용자 질문이 들어갈 자리
template = """
당신은 회사의 인사 담당 AI입니다.
아래 [규정]을 참고하여 직원의 질문에 친절하게 답해주세요.
규정에 없는 내용은 "규정에 나와있지 않습니다"라고 답하세요.

[규정]
{context}

[질문]: {question}
"""
prompt = PromptTemplate.from_template(template)

# %%
# 체인 연결 (Retrieval -> Prompt -> LLM -> Parser): LangChain Expression Language(LCEL)
# RunnablePassthrough:질문 그대로 쓰고 싶은 경우, RunnableLambda:질문을 가공하고 싶을 경우
rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %% [markdown]
# ### 실행

# %%
# ==========================================
# 5. 실행 (Test)
# ==========================================
question = "입사한 지 3년 되면 어떤 혜택이 있어? 그리고 책 사는 건 얼마나 지원해줘?"

print(f"\n 질문: {question}")
print("AI 답변 생성 중...\n")

response = rag_chain.invoke(question)

print('='*30)
print(response)
print('='*30)
# Out:
#  질문: 입사한 지 3년 되면 어떤 혜택이 있어? 그리고 책 사는 건 얼마나 지원해줘?
# AI 답변 생성 중...
#
# ==============================
# 입사한 지 3년이 지나면 안식월 1개월을 유급으로 제공받게 됩니다. 또한, 도서 구입비는 월 10만원 한도 내에서 무제한 지원됩니다.
# ==============================

# %% [markdown]
# #### 마무리 정리

# %%
# 실습 졸료 후 임시 파일 삭제
os.remove("company_policy.txt")
