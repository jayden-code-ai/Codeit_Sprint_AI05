# %% [markdown]
# # 하이브리드 검색과 리랭킹
#
# ## 하이브리드 검색
# 키워드 검색(Keyword Search)과 의미 기반 검색(Semantic Search)의 장점을 결합하여 검색 정확도를 높이는 기법
#
# RAG(Retrieval-Augmented Generation) 시스템 구축 시, 단순히 벡터 검색만 사용할 경우 고유명사나 정확한 용어 매칭이 어려울 수 있는데, 하이브리드 서치는 이를 보완(BM25 → 키워드 기반 정확한 검색, Vector Search → 의미 기반 검색)
#
# ### 키워드 검색(Sparse Retriever):
#
# - BM25 알고리즘이 대표적: 단어의 빈도와 역문서 빈도를 기반으로 작동하며, 정확한 단어 매칭에 강합니다.
#
# ### 의미 검색(Dense Retriever):
#
# - 임베딩(Embedding) 벡터 유사도(Cosine Similarity 등)를 기반: 단어가 달라도 문맥적 의미가 유사한 문서를 찾는 데 강합니다.

# %%
# !pip install langchain langchain-community rank_bm25 langchain_openai faiss-cpu
# Out:
# Requirement already satisfied: langchain in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: langchain-community in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: rank_bm25 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (0.2.2)
# Requirement already satisfied: langchain_openai in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: faiss-cpu in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (1.13.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain) (1.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain) (1.0.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (0.4.53)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.12)
# Requirement already satisfied: xxhash>=3.5.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.32.5)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (0.12.0)
# Requirement already satisfied: zstandard>=0.23.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.11.0)
# Requirement already satisfied: certifi in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.3.0)
# Requirement already satisfied: greenlet>=1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_openai) (2.8.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain_openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (0.12.0)
# Requirement already satisfied: sniffio in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2025.11.3)

# %% [markdown]
# > LangChain에서는 EnsembleRetriever 클래스를 사용하여 매우 쉽게 하이브리드 서치를 구현할 수 있습니다. 가장 일반적인 조합은 **BM25(키워드)**와 **VectorStore(의미)**의 결합입니다.

# %%
import getpass
import os

# Prompt the user for the OpenAI API key securely
os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")

# %%
from langchain_community.retrievers import BM25Retriever  # 🔎 전통적인 텍스트 검색(BM25)용 리트리버
from langchain_community.vectorstores import FAISS        # 📦 벡터 임베딩을 저장/검색하기 위한 FAISS 벡터 스토어
from langchain_openai import OpenAIEmbeddings             # 🧠 OpenAI 임베딩 모델 (텍스트 → 벡터 변환)
from langchain_core.documents import Document             # 📄 검색 결과를 표현하는 Document 객체
from langchain_core.runnables import RunnableLambda       # ⚙️ 일반 함수(hybrid_search)를 LCEL Runnable로 감싸기 위한 유틸


# 1. 샘플 데이터
docs_list = [
    "아이폰 15의 배터리 수명은 20시간입니다.",            # 문서 1: 아이폰 배터리 정보
    "갤럭시 S24는 AI 기능이 탑재되어 있습니다.",          # 문서 2: 갤럭시 AI 기능 정보
    "사과는 맛있는 과일입니다.",                        # 문서 3: 일반적인 사과(과일)에 대한 문장
    "배터리 절약 모드를 켜면 사용 시간이 늘어납니다."        # 문서 4: 배터리 절약 모드 관련 문장
]


# 2. BM25 retriever
bm25 = BM25Retriever.from_texts(docs_list)  # 📚 단순 텍스트 리스트를 BM25 인덱스로 변환하여 키워드 기반 검색 가능하게 설정
bm25.k = 2                                  # 🔢 쿼리당 상위 2개의 문서만 반환하도록 설정 (Top-k에서의 k값)


# 3. Vector retriever
embedding = OpenAIEmbeddings()                             # 🧬 각 문장을 벡터(숫자 배열)로 바꾸는 임베딩 모델 객체 생성
vectorstore = FAISS.from_texts(docs_list, embedding)       # 📦 임베딩된 벡터들을 FAISS 인덱스에 저장하여 유사도 기반 검색 준비
vec = vectorstore.as_retriever(search_kwargs={"k": 2})     # 🔎 벡터스토어를 리트리버로 래핑, 쿼리와 가장 유사한 상위 2개 문서 반환


# 4. 하이브리드 검색 함수
def hybrid_search(query):
    bm25_docs = bm25.invoke(query)   # 🧩 BM25 리트리버로 쿼리를 검색 → 키워드 기반 상위 k개 문서 리스트 반환
    vec_docs = vec.invoke(query)     # 🧩 벡터 리트리버로 쿼리를 검색 → 의미적 유사도 기반 상위 k개 문서 리스트 반환

    # 중복 제거 + 점수 재정렬
    doc_dict = {}                    # 📊 문서 내용(text)을 key로, 통합 점수를 value로 관리하기 위한 딕셔너리

    # BM25 결과 → 가중치 0.5
    for doc in bm25_docs:                                                # 🔁 BM25에서 나온 각 문서에 대해
        doc_dict[doc.page_content] = doc_dict.get(doc.page_content, 0) + 0.5  # ➕ 해당 문서의 점수에 0.5 가중치를 더함 (없으면 0에서 시작)

    # Vector 결과 → 가중치 0.5
    for doc in vec_docs:                                                 # 🔁 벡터 검색 결과에 대해서도
        doc_dict[doc.page_content] = doc_dict.get(doc.page_content, 0) + 0.5  # ➕ 동일한 방식으로 0.5를 더해 BM25와 합산 점수 구성

    # 점수 높은 순으로 정렬
    ranked_docs = sorted(                      # 📈 통합 점수를 기준으로 문서들을 정렬
        doc_dict.items(),                      #     → (문서 내용, 점수) 튜플들의 리스트
        key=lambda x: x[1],                    #     → x[1] = 점수 기준으로 정렬
        reverse=True                           #     → 점수가 높은 문서가 앞에 오게 내림차순
    )

    # Document 형태로 변환
    return [                                    # 📄 최종적으로는 LangChain의 Document 객체 리스트로 변환하여 반환
        Document(page_content=content)         #     → page_content에 실제 문서 텍스트를 넣음
        for content, _ in ranked_docs
    ]


# 5. LCEL Runnable로 감싸기
hybrid_retriever = RunnableLambda(hybrid_search)  # ⚙️ hybrid_search 함수를 LCEL 파이프라인에서 호출 가능한 Runnable 형태로 래핑

# %%
# 6. 검색
query = "스마트폰 배터리 성능"
docs = hybrid_retriever.invoke(query)

for d in docs:
    print('-', d.page_content)
# Out:
# - 배터리 절약 모드를 켜면 사용 시간이 늘어납니다.
# - 사과는 맛있는 과일입니다.
# - 아이폰 15의 배터리 수명은 20시간입니다.

# %% [markdown]
# > BM25 비중을 줄이고 싶으면 수치 ↓
# Vector 비중을 높이고 싶으면 수치 ↑
#
# 예:
#
# 더 의미 검색 중심 → BM25: 0.2, Vector: 0.8
#
# 더 키워드 중심 → BM25: 0.6, Vector: 0.4

# %% [markdown]
# ## 리랭킹(Re-ranking): "속도 vs 정확도"의 타협점
#
# - Retrieval 단계 (Bi-Encoder):
#
#     - 우리가 지금까지 배운 Vector Search나 BM25입니다.
#     - 특징: 미리 계산된 벡터를 비교하므로 속도가 엄청 빠릅니다. 하지만 질문과 문서의 디테일한 관계를 완벽히 파악하지는 못합니다. (대략적인 유사도)
#     - 비유: 서류 전형 (수천 명의 지원자 중 스펙이 비슷한 50명을 빠르게 추려냄)
#
# ### Re-ranking 단계 (Cross-Encoder):
#
# Retrieval이 뽑아온 상위 문서(예: 50개)와 질문을 **하나의 쌍(Pair)**으로 묶어서 AI 모델에 직접 넣습니다.
# - 특징: 두 문장의 관계를 깊이 있게 분석하므로 정확도가 매우 높습니다. 하지만 연산량이 많아 속도가 느립니다. (그래서 전체 문서가 아니라 상위 50개만 검사합니다.)
# - 비유: 심층 면접 (서류 통과자 50명을 한 명씩 자세히 인터뷰하여 최종 3명을 선발)
#
#
# - 요약
#     - Vector DB로 빠르고 넓게 후보를 찾고(Candidate Generation)
#     - Cross-Encoder로 정밀하게 순위를 다시 매깁니다(Re-ranking).

# %%
# !pip install langchain-huggingface sentence-transformers rank_bm25
# Out:
# Requirement already satisfied: langchain-huggingface in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: sentence-transformers in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (5.1.2)
# Requirement already satisfied: rank_bm25 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (0.2.2)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.33.4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-huggingface) (0.36.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-huggingface) (1.1.0)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-huggingface) (0.22.1)
# Requirement already satisfied: filelock in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (6.0.3)
# Requirement already satisfied: requests in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (1.2.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (0.4.53)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (2.12.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (9.1.2)
# Requirement already satisfied: jsonpointer>=1.9 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (1.0.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (0.12.0)
# Requirement already satisfied: zstandard>=0.23.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (0.25.0)
# Requirement already satisfied: anyio in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (4.11.0)
# Requirement already satisfied: certifi in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (1.0.9)
# Requirement already satisfied: idna in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (0.4.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: torch>=1.11.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from sentence-transformers) (2.9.1)
# Requirement already satisfied: scikit-learn in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from sentence-transformers) (1.4.2)
# Requirement already satisfied: scipy in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: Pillow in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from sentence-transformers) (12.0.0)
# Requirement already satisfied: numpy>=1.17 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.2.6)
# Requirement already satisfied: regex!=2019.12.17 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2.3.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (1.3.1)
# Requirement already satisfied: sniffio>=1.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.6.0)

# %%
import getpass
import os

os.environ["HF_TOKEN"] = getpass.getpass("HuggingFace Token: ")

# %%
from langchain_community.retrievers import BM25Retriever
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.cross_encoders import HuggingFaceCrossEncoder
from langchain_core.documents import Document
from langchain_core.runnables import RunnableLambda

# ------------------------------
# 1. 문서 준비
# ------------------------------
texts = [
    "강남역에서 가까운 스테이크 맛집 추천 리스트입니다. 분위기 좋은 고기 레스토랑이 많습니다.",
    "서울 강남역에서 파스타가 맛있는 이탈리안 레스토랑 리스트입니다. 크림, 토마토 파스타가 유명합니다.",   # 🎯 정답
    "강남역 맛집 전체 가이드입니다. 파스타부터 고기, 한식까지 다양한 식당을 포함합니다.",
    "서울 홍대 파스타 맛집 추천입니다. 강남역과는 거리가 꽤 있습니다.",
    "부산 남천동 파스타 맛집 리스트입니다. 부산 지역 이탈리안 맛집 모음입니다.",
    "서울 강남역 카페 추천 리스트입니다. 디저트와 커피로 유명한 곳이 많습니다."
]

# ------------------------------
# 2. BM25 Retriever
# ------------------------------
bm25 = BM25Retriever.from_texts(texts)
bm25.k = 3

# ------------------------------
# 3. Vector Retriever
# ------------------------------
embeddings = HuggingFaceEmbeddings(model_name="jhgan/ko-sroberta-multitask")
vectorstore = FAISS.from_texts(texts, embeddings)
vec = vectorstore.as_retriever(search_kwargs={"k": 3})

# ------------------------------
# 4. 하이브리드 검색 (BM25 + 벡터)
# ------------------------------
def hybrid_search(query: str):
    bm25_docs = bm25.invoke(query)
    vec_docs = vec.invoke(query)

    scores = {}

    # BM25 가중치 0.5
    for d in bm25_docs:
        scores[d.page_content] = scores.get(d.page_content, 0) + 0.5

    # Vector 가중치 0.5
    for d in vec_docs:
        scores[d.page_content] = scores.get(d.page_content, 0) + 0.5

    ranked = sorted(scores.items(), key=lambda x: x[1], reverse=True)
    return [Document(page_content=c) for c, _ in ranked]

hybrid_retriever = RunnableLambda(hybrid_search)

# %%
# ------------------------------
# 5. Cross-Encoder 로 직접 Re-rank
# ------------------------------
cross_encoder = HuggingFaceCrossEncoder(model_name="BAAI/bge-reranker-base") #문장 비교 특화 모델

def rerank_with_cross_encoder(query: str, docs, top_n: int=1):
    # (query, 문서) 쌍 만들기
    pairs = [(query, d.page_content) for d in docs]

    scores = list(cross_encoder.score(pairs))         # list[float]

    # 점수 기준 내림차순 정렬
    ranked = sorted(zip(docs, scores), key=lambda x: x[1], reverse=True)
    return [doc for doc, _ in ranked[:top_n]]

# %%
# ------------------------------
# 6. 리랭킹 테스트
# ------------------------------

query = "서울 강남역 파스타 맛집 추천"
candidate_docs = hybrid_retriever.invoke(query)                                             # 1단계: 하이브리드 검색
final_docs = rerank_with_cross_encoder(query, candidate_docs, top_n=1)                      # 2단계: 리랭킹

for d in final_docs:
    print("답변: ", d.page_content)
# Out:
# 답변:  서울 강남역에서 파스타가 맛있는 이탈리안 레스토랑 리스트입니다. 크림, 토마토 파스타가 유명합니다.

# %%
# ------------------------------
# 7. 테스트: RAG vs 하이브리드 vs 리랭크 비교
# ------------------------------
query = "서울 강남역 파스타 맛집 추천"

# (1) RAG 기본: 벡터 검색만 사용
vec_docs = vec.invoke(query)

# (2) 하이브리드 검색: BM25 + 벡터
hybrid_docs = hybrid_retriever.invoke(query)

# (3) 하이브리드 + CrossEncoder 리랭크 (최종 답변에 쓸 문서 1개 선택)
reranked_docs = rerank_with_cross_encoder(query, hybrid_docs, top_n=1)

print("=== 1. 벡터 검색만 사용 (RAG 기본) ===")
for i, d in enumerate(vec_docs, 1):
    print(f"{i}. {d.page_content}")

print("\n=== 2. 하이브리드 검색 (BM25 + 벡터) ===")
for i, d in enumerate(hybrid_docs, 1):
    print(f"{i}. {d.page_content}")

print("\n=== 3. 하이브리드 + CrossEncoder 리랭크 (최종 선택 문서) ===")
for d in reranked_docs:
    print("답변에 사용할 문서:", d.page_content)
# Out:
# === 1. 벡터 검색만 사용 (RAG 기본) ===
# 1. 서울 강남역에서 파스타가 맛있는 이탈리안 레스토랑 리스트입니다. 크림, 토마토 파스타가 유명합니다.
# 2. 서울 홍대 파스타 맛집 추천입니다. 강남역과는 거리가 꽤 있습니다.
# 3. 강남역 맛집 전체 가이드입니다. 파스타부터 고기, 한식까지 다양한 식당을 포함합니다.
#
# === 2. 하이브리드 검색 (BM25 + 벡터) ===
# 1. 서울 홍대 파스타 맛집 추천입니다. 강남역과는 거리가 꽤 있습니다.
# 2. 서울 강남역 카페 추천 리스트입니다. 디저트와 커피로 유명한 곳이 많습니다.
# 3. 부산 남천동 파스타 맛집 리스트입니다. 부산 지역 이탈리안 맛집 모음입니다.
# 4. 서울 강남역에서 파스타가 맛있는 이탈리안 레스토랑 리스트입니다. 크림, 토마토 파스타가 유명합니다.
# 5. 강남역 맛집 전체 가이드입니다. 파스타부터 고기, 한식까지 다양한 식당을 포함합니다.
#
# === 3. 하이브리드 + CrossEncoder 리랭크 (최종 선택 문서) ===
# 답변에 사용할 문서: 서울 강남역에서 파스타가 맛있는 이탈리안 레스토랑 리스트입니다. 크림, 토마토 파스타가 유명합니다.
