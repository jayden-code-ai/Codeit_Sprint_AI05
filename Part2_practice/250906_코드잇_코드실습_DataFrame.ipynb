# %%
def solution(n):
    i = 0
    total = 0

    if i <= n:
        i % 2 == 0
        total = i
        i += 1
        return total

solution(10)
# Out:
# 0

# %%
import numpy as np

# %%
gdp_array = np.array([6610, 7637, 8127, 8885, 10385, 12565, 13403, 12398, 8282, 10672])

# %%
gdp_array > 10000
# Out:
# array([False, False, False, False,  True,  True,  True,  True, False,
#         True])

# %%
mask = gdp_array > 10000
gdp_array[mask]
# Out:
# array([10385, 12565, 13403, 12398, 10672])

# %%
mask = gdp_array > 10000
gdp_array[gdp_array > 10000]
# Out:
# array([10385, 12565, 13403, 12398, 10672])

# %%
(gdp_array > 10000) | (gdp_array < 8000)
# Out:
# array([ True,  True, False, False,  True,  True,  True,  True, False,
#         True])

# %%
gdp_array[(gdp_array > 10000) | (gdp_array < 8000)]
# Out:
# array([ 6610,  7637, 10385, 12565, 13403, 12398, 10672])

# %%
gdp_array[(gdp_array <= 10000) & (gdp_array <= 8000)]
# Out:
# array([6610, 7637])

# %%
gdp_korea_array = np.array([12257, 11561, 13165, 14673, 16496, 19403])
gdp_us_array = np.array([36335, 37133, 38023, 39496, 41713, 44115])

# %%
gdp_korea_array.mean()
# Out:
# np.float64(14592.5)

# %%
gdp_korea_array.sum()
# Out:
# np.int64(87555)

# %%
gdp_korea_array.min()
# Out:
# np.int64(11561)

# %%
gdp_korea_array.max()
# Out:
# np.int64(19403)

# %%
for i in range(len(gdp_korea_array)):
    gdp_korea_array[i] = gdp_korea_array[i] * 1200

# %%
gdp_korea_array * 1200
# Out:
# array([14708400, 13873200, 15798000, 17607600, 19795200, 23283600])

# %%
gdp_korea_array
# Out:
# array([12257, 11561, 13165, 14673, 16496, 19403])

# %%
gdp_korea_array = gdp_korea_array * 1200

# %%
gdp_us_array - gdp_korea_array
# Out:
# array([24078, 25572, 24858, 24823, 25217, 24712])

# %%
gdp_us_array / gdp_korea_array
# Out:
# array([2.96442849, 3.21191938, 2.88818838, 2.69174675, 2.52867362,
#        2.27361748])

# %%
import matplotlib.pyplot as plt

# %%
year_array = np.array([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

stock_array = np.array([
    14.46, 19.01, 20.04, 27.59, 26.32,
    28.96, 42.31, 39.44, 73.41, 132.69
])

# %%
height_array = np.array([
    165, 164, 155, 151, 157, 162, 155, 157, 165, 162,
    165, 167, 167, 183, 180, 184, 177, 178, 175, 181,
    172, 173, 169, 172, 177, 178, 185, 186, 190, 187
])

weight_array = np.array([
    62, 59, 57, 55, 60, 58, 51, 56, 68, 64,
    57, 58, 64, 79, 73, 76, 61, 65, 83, 80,
    67, 82, 88, 62, 61, 79, 81, 68, 83, 80
])

# %%
plt.plot(year_array, stock_array)
plt.show()

# %%
plt.scatter(height_array, weight_array)
plt.show()

# %%
plt.scatter(height_array, weight_array, c='red', marker='+')
plt.title('Height and Weigth')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.show()

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'category': ['skirt', 'sweater', 'coat', 'jeans'],
    'quantity': [10, 15, 6, 11],
    'price': [30000, 60000, 95000, 35000]
})
df
# Out:
#   category  quantity  price
# 0    skirt        10  30000
# 1  sweater        15  60000
# 2     coat         6  95000
# 3    jeans        11  35000

# %%
df['quantity']
# Out:
# 0    10
# 1    15
# 2     6
# 3    11
# Name: quantity, dtype: int64

# %%
type(df['quantity'])
# Out:
# pandas.core.series.Series

# %%
df['quantity'].mean()
# Out:
# np.float64(10.5)

# %%
df['quantity'].min()
# Out:
# 6

# %%
df['quantity'] * df['price']
# Out:
# 0    300000
# 1    900000
# 2    570000
# 3    385000
# dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/study/data/burger.csv', index_col=0)
df
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Whopper                     660    49       28   40     1.0  Burgers
# Cheese Whopper              740    50       32   46     1.3  Burgers
# Double Whopper              900    49       48   58     1.0  Burgers
# Double Cheese Whopper       980    50       52   64     1.4  Burgers
# Whopper Junior              310    27       13   18     0.4  Burgers
# Bacon King                 1150    49       61   79     2.2  Burgers
# Single Stacker King         700    48       35   42     1.4  Burgers
# Double Stacker King        1050    49       61   68     NaN  Burgers
# Hamburger                   240    26       13   10     0.4  Burgers
# Cheeseburger                280    27       15   13     0.6  Burgers
# Double Hamburger            350    26       21   18     0.4  Burgers
# Double Cheeseburger         390    27       23   21     0.6  Burgers
# ...

# %%
df.head()
# Out:
#             product_name  calories  carb  protein  fat  sodium category
# 0                Whopper       660    49       28   40     1.0  Burgers
# 1         Cheese Whopper       740    50       32   46     1.3  Burgers
# 2         Double Whopper       900    49       48   58     1.0  Burgers
# 3  Double Cheese Whopper       980    50       52   64     1.4  Burgers
# 4         Whopper Junior       310    27       13   18     0.4  Burgers

# %%
df_2 = pd.read_csv('/content/drive/MyDrive/study/data/burger2.csv', header=None,
                   names=['product_name','calories','carb',	'protein','fat','sodium','category'])
df_2
# Out:
#              product_name  calories  carb  protein  fat  sodium category
# 0                 Whopper       660    49       28   40     1.0  Burgers
# 1          Cheese Whopper       740    50       32   46     1.3  Burgers
# 2          Double Whopper       900    49       48   58     1.0  Burgers
# 3   Double Cheese Whopper       980    50       52   64     1.4  Burgers
# 4          Whopper Junior       310    27       13   18     0.4  Burgers
# 5              Bacon King      1150    49       61   79     2.2  Burgers
# 6     Single Stacker King       700    48       35   42     1.4  Burgers
# 7     Double Stacker King      1050    49       61   68     NaN  Burgers
# 8               Hamburger       240    26       13   10     0.4  Burgers
# 9            Cheeseburger       280    27       15   13     0.6  Burgers
# 10       Double Hamburger       350    26       21   18     0.4  Burgers
# 11    Double Cheeseburger       390    27       23   21     0.6  Burgers
# ...

# %%
df.head()
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Whopper                     660    49       28   40     1.0  Burgers
# Cheese Whopper              740    50       32   46     1.3  Burgers
# Double Whopper              900    49       48   58     1.0  Burgers
# Double Cheese Whopper       980    50       52   64     1.4  Burgers
# Whopper Junior              310    27       13   18     0.4  Burgers

# %%
# iloc/loc : location의 약어 i는 int 정수형의 약어 iloc은 정수형태로 자료를 불러오고 loc은 이름을 토대로 로우와 컬럼을 불러온다.

df.iloc[3, 1]
# Out:
# np.int64(50)

# %%
df.iloc[[2,3], [1,2]]
# Out:
#                        carb  protein
# product_name
# Double Whopper           49       48
# Double Cheese Whopper    50       52

# %%
df.iloc[1:4, :3]
# Out:
#                        calories  carb  protein
# product_name
# Cheese Whopper              740    50       32
# Double Whopper              900    49       48
# Double Cheese Whopper       980    50       52

# %%
df.loc['Double Whopper', 'carb']
# Out:
# np.int64(49)

# %%
df.loc[['Whopper', 'Double Whopper'], 'protein']
# Out:
# product_name
# Whopper           28
# Double Whopper    48
# Name: protein, dtype: int64

# %%
df.loc[['Whopper', 'Double Whopper'], ['carb', 'protein', 'fat']]
# Out:
#                 carb  protein  fat
# product_name
# Whopper           49       28   40
# Double Whopper    49       48   58

# %%
df.loc['Double Whopper':'Bacon King']
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Double Whopper              900    49       48   58     1.0  Burgers
# Double Cheese Whopper       980    50       52   64     1.4  Burgers
# Whopper Junior              310    27       13   18     0.4  Burgers
# Bacon King                 1150    49       61   79     2.2  Burgers

# %%
df['fat']
# Out:
# product_name
# Whopper                  40
# Cheese Whopper           46
# Double Whopper           58
# Double Cheese Whopper    64
# Whopper Junior           18
# Bacon King               79
# Single Stacker King      42
# Double Stacker King      68
# Hamburger                10
# Cheeseburger             13
# Double Hamburger         18
# Double Cheeseburger      21
# Crispy Chicken           41
# Chicken Nuggets          11
# Spicy Chicken Nuggets    15
# Name: fat, dtype: int64

# %%
df['calories']
# Out:
# product_name
# Whopper                   660
# Cheese Whopper            740
# Double Whopper            900
# Double Cheese Whopper     980
# Whopper Junior            310
# Bacon King               1150
# Single Stacker King       700
# Double Stacker King      1050
# Hamburger                 240
# Cheeseburger              280
# Double Hamburger          350
# Double Cheeseburger       390
# Crispy Chicken            670
# Chicken Nuggets           170
# Spicy Chicken Nuggets     210
# Name: calories, dtype: int64

# %%
df['calories'] < 500
# Out:
# product_name
# Whopper                  False
# Cheese Whopper           False
# Double Whopper           False
# Double Cheese Whopper    False
# Whopper Junior            True
# Bacon King               False
# Single Stacker King      False
# Double Stacker King      False
# Hamburger                 True
# Cheeseburger              True
# Double Hamburger          True
# Double Cheeseburger       True
# Crispy Chicken           False
# Chicken Nuggets           True
# Spicy Chicken Nuggets     True
# Name: calories, dtype: bool

# %%
df.loc[df['calories'] < 500]
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Whopper Junior              310    27       13   18     0.4  Burgers
# Hamburger                   240    26       13   10     0.4  Burgers
# Cheeseburger                280    27       15   13     0.6  Burgers
# Double Hamburger            350    26       21   18     0.4  Burgers
# Double Cheeseburger         390    27       23   21     0.6  Burgers
# Chicken Nuggets             170    11        8   11     0.3  Chicken
# Spicy Chicken Nuggets       210    11        8   15     0.6  Chicken

# %%
df.loc[df['calories'] < 500, ['carb', 'protein']]
# Out:
#                        carb  protein
# product_name
# Whopper Junior           27       13
# Hamburger                26       13
# Cheeseburger             27       15
# Double Hamburger         26       21
# Double Cheeseburger      27       23
# Chicken Nuggets          11        8
# Spicy Chicken Nuggets    11        8

# %%
df[df['calories'] < 500]
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Whopper Junior              310    27       13   18     0.4  Burgers
# Hamburger                   240    26       13   10     0.4  Burgers
# Cheeseburger                280    27       15   13     0.6  Burgers
# Double Hamburger            350    26       21   18     0.4  Burgers
# Double Cheeseburger         390    27       23   21     0.6  Burgers
# Chicken Nuggets             170    11        8   11     0.3  Chicken
# Spicy Chicken Nuggets       210    11        8   15     0.6  Chicken

# %%
mask = df['calories'] < 500
mask
# Out:
# product_name
# Whopper                  False
# Cheese Whopper           False
# Double Whopper           False
# Double Cheese Whopper    False
# Whopper Junior            True
# Bacon King               False
# Single Stacker King      False
# Double Stacker King      False
# Hamburger                 True
# Cheeseburger              True
# Double Hamburger          True
# Double Cheeseburger       True
# Crispy Chicken           False
# Chicken Nuggets           True
# Spicy Chicken Nuggets     True
# Name: calories, dtype: bool

# %%
df
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Whopper                     660    49       28   40     1.0  Burgers
# Cheese Whopper              740    50       32   46     1.3  Burgers
# Double Whopper              900    49       48   58     1.0  Burgers
# Double Cheese Whopper       980    50       52   64     1.4  Burgers
# Whopper Junior              310    27       13   18     0.4  Burgers
# Bacon King                 1150    49       61   79     2.2  Burgers
# Single Stacker King         700    48       35   42     1.4  Burgers
# Double Stacker King        1050    49       61   68     NaN  Burgers
# Hamburger                   240    26       13   10     0.4  Burgers
# Cheeseburger                280    27       15   13     0.6  Burgers
# Double Hamburger            350    26       21   18     0.4  Burgers
# Double Cheeseburger         390    27       23   21     0.6  Burgers
# ...

# %%
df.loc['Double Stacker King','sodium']
# Out:
# np.float64(nan)

# %%
df.loc['Double Stacker King','sodium'] = 1.9

# %%
df
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Whopper                     660    49       28   40     1.0  Burgers
# Cheese Whopper              740    50       32   46     1.3  Burgers
# Double Whopper              900    49       48   58     1.0  Burgers
# Double Cheese Whopper       980    50       52   64     1.4  Burgers
# Whopper Junior              310    27       13   18     0.4  Burgers
# Bacon King                 1150    49       61   79     2.2  Burgers
# Single Stacker King         700    48       35   42     1.4  Burgers
# Double Stacker King        1050    49       61   68     1.9  Burgers
# Hamburger                   240    26       13   10     0.4  Burgers
# Cheeseburger                280    27       15   13     0.6  Burgers
# Double Hamburger            350    26       21   18     0.4  Burgers
# Double Cheeseburger         390    27       23   21     0.6  Burgers
# ...

# %%
df.loc['Cheeseburger']
# Out:
# calories        280
# carb             27
# protein          15
# fat              13
# sodium          0.6
# category    Burgers
# Name: Cheeseburger, dtype: object

# %%
df.loc['Cheeseburger'] = [360, 24, 18, 21, 0.7, 'Burgers']

# %%
df
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Whopper                     660    49       28   40     1.0  Burgers
# Cheese Whopper              740    50       32   46     1.3  Burgers
# Double Whopper              900    49       48   58     1.0  Burgers
# Double Cheese Whopper       980    50       52   64     1.4  Burgers
# Whopper Junior              310    27       13   18     0.4  Burgers
# Bacon King                 1150    49       61   79     2.2  Burgers
# Single Stacker King         700    48       35   42     1.4  Burgers
# Double Stacker King        1050    49       61   68     1.9  Burgers
# Hamburger                   240    26       13   10     0.4  Burgers
# Cheeseburger                360    24       18   21     0.7  Burgers
# Double Hamburger            350    26       21   18     0.4  Burgers
# Double Cheeseburger         390    27       23   21     0.6  Burgers
# ...

# %%
df['sodium']
# Out:
# product_name
# Whopper                  1.0
# Cheese Whopper           1.3
# Double Whopper           1.0
# Double Cheese Whopper    1.4
# Whopper Junior           0.4
# Bacon King               2.2
# Single Stacker King      1.4
# Double Stacker King      1.9
# Hamburger                0.4
# Cheeseburger             0.7
# Double Hamburger         0.4
# Double Cheeseburger      0.6
# Crispy Chicken           1.1
# Chicken Nuggets          0.3
# Spicy Chicken Nuggets    0.6
# Name: sodium, dtype: float64

# %%
df['sodium'] = 123

# %%
df
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Whopper                     660    49       28   40     123  Burgers
# Cheese Whopper              740    50       32   46     123  Burgers
# Double Whopper              900    49       48   58     123  Burgers
# Double Cheese Whopper       980    50       52   64     123  Burgers
# Whopper Junior              310    27       13   18     123  Burgers
# Bacon King                 1150    49       61   79     123  Burgers
# Single Stacker King         700    48       35   42     123  Burgers
# Double Stacker King        1050    49       61   68     123  Burgers
# Hamburger                   240    26       13   10     123  Burgers
# Cheeseburger                360    24       18   21     123  Burgers
# Double Hamburger            350    26       21   18     123  Burgers
# Double Cheeseburger         390    27       23   21     123  Burgers
# ...

# %%
df.loc['Tripple Whopper'] = [1130, 49, 67, 75, 1.1, 'Burger']
df
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Whopper                     660    49       28   40   123.0  Burgers
# Cheese Whopper              740    50       32   46   123.0  Burgers
# Double Whopper              900    49       48   58   123.0  Burgers
# Double Cheese Whopper       980    50       52   64   123.0  Burgers
# Whopper Junior              310    27       13   18   123.0  Burgers
# Bacon King                 1150    49       61   79   123.0  Burgers
# Single Stacker King         700    48       35   42   123.0  Burgers
# Double Stacker King        1050    49       61   68   123.0  Burgers
# Hamburger                   240    26       13   10   123.0  Burgers
# Cheeseburger                360    24       18   21   123.0  Burgers
# Double Hamburger            350    26       21   18   123.0  Burgers
# Double Cheeseburger         390    27       23   21   123.0  Burgers
# ...

# %%
df['brand'] = 'Burger King'
df
# Out:
#                        calories  carb  protein  fat  sodium category  \
# product_name
# Whopper                     660    49       28   40   123.0  Burgers
# Cheese Whopper              740    50       32   46   123.0  Burgers
# Double Whopper              900    49       48   58   123.0  Burgers
# Double Cheese Whopper       980    50       52   64   123.0  Burgers
# Whopper Junior              310    27       13   18   123.0  Burgers
# Bacon King                 1150    49       61   79   123.0  Burgers
# Single Stacker King         700    48       35   42   123.0  Burgers
# Double Stacker King        1050    49       61   68   123.0  Burgers
# Hamburger                   240    26       13   10   123.0  Burgers
# Cheeseburger                360    24       18   21   123.0  Burgers
# Double Hamburger            350    26       21   18   123.0  Burgers
# Double Cheeseburger         390    27       23   21   123.0  Burgers
# ...

# %%
df.loc[df['calories'] >= 500]
# Out:
#                        calories  carb  protein  fat  sodium category  \
# product_name
# Whopper                     660    49       28   40   123.0  Burgers
# Cheese Whopper              740    50       32   46   123.0  Burgers
# Double Whopper              900    49       48   58   123.0  Burgers
# Double Cheese Whopper       980    50       52   64   123.0  Burgers
# Bacon King                 1150    49       61   79   123.0  Burgers
# Single Stacker King         700    48       35   42   123.0  Burgers
# Double Stacker King        1050    49       61   68   123.0  Burgers
# Crispy Chicken              670    54       23   41   123.0  Chicken
# Tripple Whopper            1130    49       67   75     1.1   Burger
#
#                              brand
# product_name
# Whopper                Burger King
# Cheese Whopper         Burger King
# Double Whopper         Burger King
# Double Cheese Whopper  Burger King
# Bacon King             Burger King
# ...

# %%
df.loc[df['calories'] >= 500, 'high_calorie'] = True
df.loc[df['calories'] < 500, 'high_calorie'] = False
df
# Out:
#                        calories  carb  protein  fat  sodium category  \
# product_name
# Whopper                     660    49       28   40   123.0  Burgers
# Cheese Whopper              740    50       32   46   123.0  Burgers
# Double Whopper              900    49       48   58   123.0  Burgers
# Double Cheese Whopper       980    50       52   64   123.0  Burgers
# Whopper Junior              310    27       13   18   123.0  Burgers
# Bacon King                 1150    49       61   79   123.0  Burgers
# Single Stacker King         700    48       35   42   123.0  Burgers
# Double Stacker King        1050    49       61   68   123.0  Burgers
# Hamburger                   240    26       13   10   123.0  Burgers
# Cheeseburger                360    24       18   21   123.0  Burgers
# Double Hamburger            350    26       21   18   123.0  Burgers
# Double Cheeseburger         390    27       23   21   123.0  Burgers
# ...
