# %%
import pandas as pd
import numpy as np

from sklearn import preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
nba_df = pd.read_csv('/content/drive/MyDrive/study/data/NBA_player_of_the_week.csv')
nba_df
# Out:
#                       Player                    Team Conference          Date  \
# 0               Jayson Tatum          Boston Celtics       East  Feb 10, 2020
# 1               Nikola Jokic          Denver Nuggets       West  Feb 10, 2020
# 2               Jaylen Brown          Boston Celtics       East   Feb 3, 2020
# 3             Damian Lillard  Portland Trail Blazers       West   Feb 3, 2020
# 4              Pascal Siakam         Toronto Raptors       East  Jan 27, 2020
# ...                      ...                     ...        ...           ...
# 1335               Phil Ford       Kansas City Kings        NaN  Nov 18, 1979
# 1336           Magic Johnson      Los Angeles Lakers        NaN  Nov 11, 1979
# 1337         Marques Johnson         Milwaukee Bucks        NaN   Nov 4, 1979
# 1338  Micheal Ray Richardson         New York Knicks        NaN  Oct 28, 1979
# 1339           Julius Erving     Philadelphia Sixers        NaN  Oct 21, 1979
#
# ...

# %%
nba_df.describe(include='all')
# Out:
#               Player                Team Conference          Date Position  \
# count           1340                1340        839          1340     1340
# unique           333                  37          2           916       11
# top     LeBron James  Los Angeles Lakers       East  Jan 12, 2003        G
# freq              63                  87        420             3      200
# mean             NaN                 NaN        NaN           NaN      NaN
# std              NaN                 NaN        NaN           NaN      NaN
# min              NaN                 NaN        NaN           NaN      NaN
# 25%              NaN                 NaN        NaN           NaN      NaN
# 50%              NaN                 NaN        NaN           NaN      NaN
# 75%              NaN                 NaN        NaN           NaN      NaN
# max              NaN                 NaN        NaN           NaN      NaN
#
# ...

# %%
height_weight_age_df = nba_df[['Height CM', 'Weight KG', 'Age']]
height_weight_age_df
# Out:
#       Height CM  Weight KG  Age
# 0           203         94   21
# 1           213        113   25
# 2           201         99   23
# 3           190         88   29
# 4           206        104   25
# ...         ...        ...  ...
# 1335        188         79   24
# 1336        206        115   20
# 1337        201         98   24
# 1338        196         85   24
# 1339        198         90   30
#
# [1340 rows x 3 columns]

# %%
scaler = preprocessing.MinMaxScaler()
normal = scaler.fit_transform(height_weight_age_df)
normal
# Out:
# array([[0.51851852, 0.32911392, 0.0952381 ],
#        [0.7037037 , 0.56962025, 0.28571429],
#        [0.48148148, 0.39240506, 0.19047619],
#        ...,
#        [0.48148148, 0.37974684, 0.23809524],
#        [0.38888889, 0.21518987, 0.23809524],
#        [0.42592593, 0.27848101, 0.52380952]])

# %%
normal_df = pd.DataFrame(normal, columns=['Height CM', 'Weight KG', 'Age'])
normal_df.describe()
# Out:
#        Height CM  Weight KG        Age
# count 1340.00000 1340.00000 1340.00000
# mean     0.48281    0.42259    0.36848
# std      0.17348    0.17736    0.16194
# min      0.00000    0.00000    0.00000
# 25%      0.33333    0.31646    0.23810
# 50%      0.48148    0.39241    0.33333
# 75%      0.61111    0.56962    0.47619
# max      1.00000    1.00000    1.00000

# %% [markdown]
# 데이터의 맥스와 미니엄 값을보면 0과 1로 잘 변경되었다.

# %%
# # 필요한 도구 import
# from sklearn import preprocessing
# import pandas as pd

# PATIENT_FILE_PATH = './datasets/liver_patient_data.csv'
# pd.set_option('display.float_format', lambda x: '%.5f' % x)

# # 데이터 파일을 pandas dataframe으로 가지고 온다
# liver_patients_df = pd.read_csv(PATIENT_FILE_PATH)

# # Normalization할 열 이름들
# features_to_normalize = liver_patients_df[['Total_Bilirubin','Direct_Bilirubin', 'Alkaline_Phosphotase', 'Alamine_Aminotransferase']]

# # 여기에 코드를 작성하세요
# scaler = preprocessing.MinMaxScaler()
# normalized = scaler.fit_transform(features_to_normalize)
# normalized_df = pd.DataFrame(normalized, columns=['Total_Bilirubin','Direct_Bilirubin', 'Alkaline_Phosphotase', 'Alamine_Aminotransferase'])
# # 테스트 코드
# normalized_df.describe()
