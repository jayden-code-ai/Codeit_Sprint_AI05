# %% [markdown]
# # LangChain & LangSmith 실습: 한국어 FAQ 챗봇 만들기
#
# ## 학습 목표
# 1. LangChain의 핵심 컴포넌트 이해 및 활용
# 2. RAG(Retrieval Augmented Generation) 시스템 구축
# 3. LangSmith를 통한 모니터링 및 디버깅: 로그인후에 API 키 생성
#     - https://smith.langchain.com/
# 4. 실전 FAQ 챗봇 개발
#
# ## 시나리오
# IT 회사 FAQ 챗봇: 직원들의 자주 묻는 질문에 자동으로 답변하는 시스템

# %% [markdown]
# ### step 1: 환경설정

# %%
# !pip install langchain langchain-openai langchain-community langsmith
# !pip install chromadb tiktoken
# !pip install python-dotenv
# Out:
# Requirement already satisfied: langchain in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: langchain-openai in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: langchain-community in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: langsmith in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (0.4.53)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain) (1.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain) (1.0.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (4.15.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith) (2.32.5)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith) (0.12.0)
# Requirement already satisfied: zstandard>=0.23.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langsmith) (0.25.0)
# Requirement already satisfied: anyio in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith) (4.11.0)
# Requirement already satisfied: certifi in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith) (1.0.9)
# Requirement already satisfied: idna in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.12)
# Requirement already satisfied: xxhash>=3.5.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-openai) (2.8.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: sniffio in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from requests>=2.0.0->langsmith) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from requests>=2.0.0->langsmith) (2.3.0)
# Requirement already satisfied: greenlet>=1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: chromadb in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (1.3.5)
# Requirement already satisfied: tiktoken in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (0.12.0)
# Requirement already satisfied: build>=1.0.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (2.12.4)
# Requirement already satisfied: pybase64>=1.4.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.38.0)
# Requirement already satisfied: numpy>=1.22.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (2.2.6)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (3.11.4)
# Requirement already satisfied: httpx>=0.27.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: requests<3.0,>=2.7 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.11.12)
# Requirement already satisfied: regex>=2022.1.18 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: packaging>=19.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: pyproject_hooks in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (2.3.0)
# Requirement already satisfied: anyio in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (0.29.0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.1)
# Requirement already satisfied: sympy in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-proto==1.39.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from tokenizers>=0.13.2->chromadb) (0.36.0)
# Requirement already satisfied: filelock in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.2.0)
# Requirement already satisfied: click>=8.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.1)
# Requirement already satisfied: uvloop>=0.15.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: sniffio>=1.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: python-dotenv in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (1.2.1)

# %%
import os
from getpass import getpass

# API 키 설정
os.environ["OPENAI_API_KEY"] = getpass("OpenAI API Key: ")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = getpass("LangSmith API Key: ")
os.environ["LANGCHAIN_PROJECT"] = "korean-faq-chatbot-2"            # 프로젝트 이름

# %% [markdown]
# ### Step 2: FAQ 데이터 준비
#
# 실제 회사에서 사용할 법한 HR FAQ 데이터를 준비합니다.

# %%
# FAQ 데이터 (실제로는 파일이나 DB에서 가져옴)
faq_data = [
    {
        "질문": "연차는 어떻게 신청하나요?",
        "답변": "연차 신청은 사내 그룹웨어의 '전자결재' 메뉴에서 '휴가신청서'를 작성하면 됩니다. 최소 3일 전에 신청해야 하며, 팀장의 승인이 필요합니다. 긴급한 경우 전화로 먼저 알리고 사후 처리도 가능합니다."
    },
    {
        "질문": "월급날은 언제인가요?",
        "답변": "급여는 매월 25일에 지급됩니다. 25일이 주말이나 공휴일인 경우, 그 전 영업일에 지급됩니다. 급여명세서는 급여일 오전에 이메일로 발송됩니다."
    },
    {
        "질문": "재택근무 신청 방법을 알려주세요",
        "답변": "재택근무는 주 2회까지 가능합니다. 전날 오후 6시까지 팀장에게 슬랙으로 신청하면 됩니다. 재택근무 중에도 오전 10시-오후 5시는 업무 가능 상태여야 하며, 화상회의 참석이 가능해야 합니다."
    },
    {
        "질문": "건강검진은 언제 받나요?",
        "답변": "연간 건강검진은 입사 기념월에 받을 수 있습니다. 회사가 지정한 병원 리스트 중에서 선택 가능하며, 비용은 회사에서 전액 지원합니다. 인사팀으로 연락하시면 예약을 도와드립니다."
    },
    {
        "질문": "야근 수당은 어떻게 되나요?",
        "답변": "평일 오후 7시 이후 근무에 대해서는 야근 수당이 지급됩니다. 그룹웨어에서 야근 신청을 하고 팀장 승인을 받아야 합니다. 야근 수당은 시간당 기본급의 1.5배로 계산되며, 다음 달 급여에 포함됩니다."
    },
    {
        "질문": "경조사 휴가 기준은?",
        "답변": "경조사 휴가는 다음과 같이 제공됩니다. 본인 결혼: 5일, 자녀 결혼: 1일, 부모/배우자 부모 사망: 5일, 조부모/형제자매 사망: 3일. 경조사 발생 시 인사팀에 경조사 증빙서류를 제출해주세요."
    },
    {
        "질문": "점심시간은 몇 시부터 몇 시까지인가요?",
        "답변": "점심시간은 오후 12시부터 1시까지 1시간입니다. 팀별로 상황에 따라 11시 30분~1시 30분 사이에 탄력적으로 운영 가능합니다. 점심시간에는 자유롭게 외출 가능합니다."
    },
    {
        "질문": "사내 교육 프로그램이 있나요?",
        "답변": "분기별로 직무 교육과 온라인 교육 플랫폼을 제공합니다. 외부 교육이 필요한 경우 연간 100만원 한도 내에서 지원받을 수 있습니다. 교육 신청은 그룹웨어의 '교육신청' 메뉴에서 가능합니다."
    },
    {
        "질문": "주차는 어떻게 하나요?",
        "답변": "지하 주차장 이용이 가능하며, 입사 시 차량번호를 등록해야 합니다. 주차 공간이 한정되어 있어 선착순으로 배정됩니다. 주차 등록은 총무팀으로 신청하시면 됩니다."
    },
    {
        "질문": "복지 포인트는 어떻게 사용하나요?",
        "답변": "매년 1월 1일 기준으로 연간 150만원의 복지 포인트가 지급됩니다. 제휴 쇼핑몰에서 도서, 영화, 여행, 건강 등 다양한 분야에 사용 가능합니다. 사용 방법은 인사팀에서 발송하는 복지 가이드를 참조하세요."
    }
]

print(f"총 {len(faq_data)}개의 FAQ 데이터가 준비되었습니다.")
print("\n예시:")
print(f"Q: {faq_data[0]['질문']}")
print(f"A: {faq_data[0]['답변'][:50]}...")
# Out:
# 총 10개의 FAQ 데이터가 준비되었습니다.
#
# 예시:
# Q: 연차는 어떻게 신청하나요?
# A: 연차 신청은 사내 그룹웨어의 '전자결재' 메뉴에서 '휴가신청서'를 작성하면 됩니다. 최소 ...

# %% [markdown]
# ### Step 3: 기본 LangChain 챗봅(RAG없이)
#
# 먼저 간단한 LLM 기반 챗봇을 만들어 봅니다.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# LLM 초기화
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0               # 일관된 답변을 위해 0으로 설정
)

# 프롬프트 템플릿
template = """
당신은 친천한 HR 담당자 압니다.
직원의 질문에 정확하고 친절하게 답변 해주세요.

질문: {question}
답변:
"""

prompt = ChatPromptTemplate.from_template(template)

# 체인구성
basic_chain = prompt | llm | StrOutputParser()

# 테스트
question = "연차는 어떻게 신청하나요?"
response = basic_chain.invoke({"question": question})
print(f"질문: {question}")
print(f"\n답변: {response}")
# Out:
# 질문: 연차는 어떻게 신청하나요?
#
# 답변: 안녕하세요! 연차 신청 방법에 대해 안내해 드리겠습니다.
#
# 1. **신청서 작성**: 연차를 사용하고자 하는 날짜를 포함하여 연차 신청서를 작성해 주세요. 회사의 연차 신청 양식이 있다면 해당 양식을 사용하시면 됩니다.
#
# 2. **상사 승인**: 작성한 신청서를 상사에게 제출하여 승인을 받아야 합니다. 상사와의 대화에서 연차 사용 이유를 간단히 설명해 주시면 좋습니다.
#
# 3. **인사팀 제출**: 상사의 승인을 받은 후, 최종 신청서를 인사팀에 제출해 주세요. 이때, 필요한 경우 추가 서류를 요청할 수 있습니다.
#
# 4. **확인**: 인사팀에서 연차 사용이 승인되면, 확인 메일이나 문서를 통해 통보해 드립니다.
#
# 연차 사용에 대한 추가 질문이 있으시면 언제든지 문의해 주세요! 감사합니다.

# %% [markdown]
# ### 🤔 문제점
# - LLM이 일반적인 지식으로만 답변
# - 회사 특정 정책을 모름
# - 잘못된 정보를 제공할 수 있음 (환각 현상)
#
# → **RAG를 사용하여 해결!**

# %% [markdown]
# ### Step 4: RAG 기반 FAQ Chatbot 구현

# %%
## 4_1. 백터 DB생성

from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_core.documents import Document

# FAQ를 Document로 변환
documents =[]
for faq in faq_data:
    doc = Document(
        page_content=f"질문: {faq['질문']}\n답변: {faq['답변']}",
        metadata={"source": "HR FAQ", "question": faq['질문']}
    )
    documents.append(doc)

print(f"총 {len(documents)}개의 문서가 생성되었습니다.")
print("\n예시:")
print(documents[0].page_content)
# Out:
# 총 10개의 문서가 생성되었습니다.
#
# 예시:
# 질문: 연차는 어떻게 신청하나요?
# 답변: 연차 신청은 사내 그룹웨어의 '전자결재' 메뉴에서 '휴가신청서'를 작성하면 됩니다. 최소 3일 전에 신청해야 하며, 팀장의 승인이 필요합니다. 긴급한 경우 전화로 먼저 알리고 사후 처리도 가능합니다.

# %%
# embedding 모델 초기화

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# vector DB 생성
vectorstore = Chroma.from_documents(
    documents=documents,
    embedding=embeddings,
    collection_name="hr_faq"
)

print("벡터 DB가 생성되었습니다!")
# Out:
# 벡터 DB가 생성되었습니다!

# %%
# 4_2. 검색테스트

# 유사도 검사 테스트
query = "휴가 신청은 어떻게 해요?"
results = vectorstore.similarity_search(query, k=3)

print(f"검색 쿼리: {query}\n")
print("검색 결과:")
for i, doc in enumerate(results, 1):
    print(f"\n[결과 {i}]")
    print(doc.page_content)
    print(f"메타데이터: {doc.metadata}")
# Out:
# 검색 쿼리: 휴가 신청은 어떻게 해요?
#
# 검색 결과:
#
# [결과 1]
# 질문: 연차는 어떻게 신청하나요?
# 답변: 연차 신청은 사내 그룹웨어의 '전자결재' 메뉴에서 '휴가신청서'를 작성하면 됩니다. 최소 3일 전에 신청해야 하며, 팀장의 승인이 필요합니다. 긴급한 경우 전화로 먼저 알리고 사후 처리도 가능합니다.
# 메타데이터: {'question': '연차는 어떻게 신청하나요?', 'source': 'HR FAQ'}
#
# [결과 2]
# 질문: 경조사 휴가 기준은?
# 답변: 경조사 휴가는 다음과 같이 제공됩니다. 본인 결혼: 5일, 자녀 결혼: 1일, 부모/배우자 부모 사망: 5일, 조부모/형제자매 사망: 3일. 경조사 발생 시 인사팀에 경조사 증빙서류를 제출해주세요.
# 메타데이터: {'question': '경조사 휴가 기준은?', 'source': 'HR FAQ'}
#
# [결과 3]
# 질문: 주차는 어떻게 하나요?
# 답변: 지하 주차장 이용이 가능하며, 입사 시 차량번호를 등록해야 합니다. 주차 공간이 한정되어 있어 선착순으로 배정됩니다. 주차 등록은 총무팀으로 신청하시면 됩니다.
# 메타데이터: {'question': '주차는 어떻게 하나요?', 'source': 'HR FAQ'}

# %%
# 4_3. RAG 체인 구성

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableParallel, RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI

retriever = vectorstore.as_retriever(search_kwargs={"k": 3})

# RAG 프롬프트 템플릿
rag_template = """당신은 회사의 HR 챗봇입니다.
아래 제공된 FAQ 정보를 바탕으로 직원의 질문에 정확하고 친절하게 답변해주세요.

FAQ 정보:
{context}

질문: {question}

답변 가이드:
1. FAQ에 정확한 답변이 있으면 그대로 전달하세요
2. FAQ에 없는 내용이면 "정확한 정보는 인사팀(내선 1234)으로 문의해주세요"라고 안내하세요
3. 친절하고 전문적인 톤을 유지하세요

답변:"""

# ChatPromptTemplate 사용
rag_prompt = ChatPromptTemplate.from_template(rag_template)

# 답변만 만드는 RAG 체인(LCEL)
answer_chain = (
    RunnableParallel(
        context=retriever,                # question을 retriever에 그대로 넣음
        question=RunnablePassthrough()    # question은 그대로 다음으로 전달
    )
    | rag_prompt
    | llm
    | StrOutputParser()
)

# "답변 + 출처 문서" 둘 다 반환하는 체인
qa_chain = RunnableParallel(
    answer=answer_chain,
    source_documents=retriever
)

print('=== RAG 체인이 생성되었습니다.')
# Out:
# === RAG 체인이 생성되었습니다.

# %%
# 테스트 실행
query = "연차에 대해 알고 싶어"
result = qa_chain.invoke(query)

print("---답변:")
print(result['answer'])
print('\n--- 사용된 문서 수:', len(result["source_documents"]))
# Out:
# ---답변:
# 연차 신청은 사내 그룹웨어의 '전자결재' 메뉴에서 '휴가신청서'를 작성하시면 됩니다. 최소 3일 전에 신청해야 하며, 팀장의 승인이 필요합니다. 긴급한 경우에는 전화로 먼저 알리고 사후 처리도 가능합니다. 추가로 궁금한 점이 있으시면 언제든지 문의해 주세요!
#
# --- 사용된 문서 수: 3

# %%
def ask_faq(question):
    """FAQ 챗봇에게 질문하기"""
    result = qa_chain.invoke(question)  # query dict 필요 없음

    answer = result["answer"]
    sources = result["source_documents"]

    print(f"💬 질문: {question}")
    print(f"\n🤖 답변: {answer}")
    print(f"\n📚 참고한 문서 수: {len(sources)}")

    if len(sources) > 0:
        print("\n관련 FAQ:")
        for i, doc in enumerate(sources, 1):
            # 문서의 메타데이터에 FAQ의 질문이 있다고 가정
            q = doc.metadata.get("question", "(질문 정보 없음)")
            print(f"  {i}. {q}")

    print("\n" + "="*80 + "\n")
    return result

# %%
# 테스트 질문들
test_questions = [
    "연차는 어떻게 신청하나요?",
    "급여일이 언제에요?",
    "재택근무 가능한가요?",
    "회사에서 주식 투자 교육을 받을 수 있나요?"  # FAQ에 없는 질문
]

for q in test_questions:
    ask_faq(q)
# Out:
# 💬 질문: 연차는 어떻게 신청하나요?
#
# 🤖 답변: 연차 신청은 사내 그룹웨어의 '전자결재' 메뉴에서 '휴가신청서'를 작성하면 됩니다. 최소 3일 전에 신청해야 하며, 팀장의 승인이 필요합니다. 긴급한 경우에는 전화로 먼저 알리고 사후 처리도 가능합니다. 추가로 궁금한 점이 있으시면 언제든지 문의해 주세요!
#
# 📚 참고한 문서 수: 3
#
# 관련 FAQ:
#   1. 연차는 어떻게 신청하나요?
#   2. 주차는 어떻게 하나요?
#   3. 재택근무 신청 방법을 알려주세요
#
# ================================================================================
#
# 💬 질문: 급여일이 언제에요?
#
# 🤖 답변: 급여는 매월 25일에 지급됩니다. 만약 25일이 주말이나 공휴일인 경우, 그 전 영업일에 지급됩니다. 급여명세서는 급여일 오전에 이메일로 발송됩니다. 추가로 궁금한 사항이 있으시면 언제든지 문의해 주세요!
#
# 📚 참고한 문서 수: 3
#
# 관련 FAQ:
#   1. 월급날은 언제인가요?
#   2. 야근 수당은 어떻게 되나요?
#   3. 경조사 휴가 기준은?
#
# ================================================================================
#
# 💬 질문: 재택근무 가능한가요?
#
# 🤖 답변: 재택근무는 주 2회까지 가능합니다. 전날 오후 6시까지 팀장에게 슬랙으로 신청하시면 됩니다. 재택근무 중에도 오전 10시부터 오후 5시까지는 업무 가능 상태여야 하며, 화상회의 참석이 가능해야 합니다. 추가로 궁금한 점이 있으시면 언제든지 문의해 주세요!
#
# 📚 참고한 문서 수: 3
#
# 관련 FAQ:
#   1. 재택근무 신청 방법을 알려주세요
#   2. 연차는 어떻게 신청하나요?
#   3. 주차는 어떻게 하나요?
#
# ================================================================================
#
# 💬 질문: 회사에서 주식 투자 교육을 받을 수 있나요?
#
# 🤖 답변: 현재 제공된 FAQ 정보에는 주식 투자 교육에 대한 내용이 포함되어 있지 않습니다. 정확한 정보는 인사팀(내선 1234)으로 문의해 주시기 바랍니다. 도움이 필요하시면 언제든지 말씀해 주세요!
#
# 📚 참고한 문서 수: 3
#
# 관련 FAQ:
#   1. 사내 교육 프로그램이 있나요?
#   2. 건강검진은 언제 받나요?
#   3. 복지 포인트는 어떻게 사용하나요?
#
# ================================================================================

# %% [markdown]
# ## Step 5: LangSmith 모니터링
#
# LangSmith에서 다음을 확인할 수 있습니다:
# - 전체 체인 실행 과정
# - 각 단계별 소요 시간
# - 사용한 토큰 수와 비용
# - 검색된 문서들
# - LLM의 입출력
#
# 👉 https://smith.langchain.com 에서 'korean-faq-chatbot' 프로젝트를 확인하세요!

# %% [markdown]
# ### Step 6: 대화 기록 기능 추가(Memory)

# %%
from operator import itemgetter

from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables import RunnableWithMessageHistory
from langchain_core.output_parsers import StrOutputParser
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_openai import ChatOpenAI

# 1) LLM & retriever 준비
llm = ChatOpenAI(model="gpt-4o-mini")  # 예시, 이미 있으시면 이건 생략
retriever = vectorstore.as_retriever(search_kwargs={"k": 3})

# 2) HR FAQ RAG 프롬프트 (대화 기록 + 컨텍스트 + 질문)
rag_template = """당신은 회사의 HR 챗봇입니다.
아래 제공된 FAQ 정보를 바탕으로 직원의 질문에 정확하고 친절하게 답변해주세요.

FAQ 정보:
{context}

질문: {question}

답변 가이드:
1. FAQ에 정확한 답변이 있으면 그대로 전달하세요
2. FAQ에 없는 내용이면 "정확한 정보는 인사팀(내선 1234)으로 문의해주세요"라고 안내하세요
3. 친절하고 전문적인 톤을 유지하세요

답변:"""

rag_prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        "당신은 회사의 HR 챗봇입니다. "
        "FAQ와 이전 대화를 바탕으로 직원의 질문에 정확하고 친절하게 답변해주세요."
    ),
    MessagesPlaceholder("chat_history"),
    ("human", rag_template),
])

# 3) base_rag_chain: question + chat_history → context 검색 → LLM 호출

base_rag_chain = (
    {
        # question만 뽑아서 retriever에 넣어서 context 생성
        "context": itemgetter("question") | retriever,
        "question": itemgetter("question"),
        "chat_history": itemgetter("chat_history"),
    }
    | rag_prompt
    | llm
    | StrOutputParser()
)

# 4) 세션별 대화 히스토리 저장소
store = {}

def get_session_history(session_id: str):
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()
    return store[session_id]

# 5) 대화형 체인으로 래핑
conversational_chain = RunnableWithMessageHistory(
    base_rag_chain,
    get_session_history,
    input_messages_key="question",     # 유저 입력이 들어오는 필드
    history_messages_key="chat_history",  # 프롬프트에서 MessagesPlaceholder 이름
)

print("대화 기록 기능이 추가된 챗봇이 준비되었습니다!")
# Out:
# 대화 기록 기능이 추가된 챗봇이 준비되었습니다!

# %%
# 6) chat() 함수 정의
def chat(question, session_id="demo-user"):
    """대화형 HR FAQ 챗봇 질의 함수"""
    result = conversational_chain.invoke(
        {"question": question, "chat_history": []},  # chat_history는 RunnableWithMessageHistory가 내부 처리
        config={"configurable": {"session_id": session_id}},
    )
    print(f"💬 질문: {question}")
    print(f"🤖 답변: {result}\n")
    return result


# 7) 연속 대화 테스트
chat("연차는 어떻게 신청하나요?")
chat("최소 몇 일 전에 신청해야 하나요?")  # 이전 맥락 따라가야 함
chat("급여는 언제 받나요?")            # 새로운 주제
# Out:
# 💬 질문: 연차는 어떻게 신청하나요?
# 🤖 답변: 연차 신청은 사내 그룹웨어의 '전자결재' 메뉴에서 '휴가신청서'를 작성하면 됩니다. 최소 3일 전에 신청해야 하며, 팀장의 승인이 필요합니다. 긴급한 경우에는 전화로 먼저 알리고 사후 처리도 가능합니다. 추가로 궁금한 점이 있으시면 언제든지 말씀해 주세요!
#
# 💬 질문: 최소 몇 일 전에 신청해야 하나요?
# 🤖 답변: 연차는 최소 3일 전에 신청해야 합니다. 더 궁금한 점이 있으시면 언제든지 말씀해 주세요!
#
# 💬 질문: 급여는 언제 받나요?
# 🤖 답변: 급여는 매월 25일에 지급됩니다. 만약 25일이 주말이나 공휴일인 경우, 그 전 영업일에 지급됩니다. 급여명세서는 급여일 오전에 이메일로 발송됩니다. 추가로 궁금한 점이 있으시면 언제든지 말씀해 주세요!
# '급여는 매월 25일에 지급됩니다. 만약 25일이 주말이나 공휴일인 경우, 그 전 영업일에 지급됩니다. 급여명세서는 급여일 오전에 이메일로 발송됩니다. 추가로 궁금한 점이 있으시면 언제든지 말씀해 주세요!'

# %% [markdown]
# ## Step 7: 성능 평가 및 개선
#
# ### 7.1 평가 데이터셋 만들기

# %%
# 평가용 질문-답변 쌍
eval_data = [
    {
        "question": "연차 신청은 어떻게 하나요?",
        "expected_keywords": ["그룹웨어", "전자결재", "3일 전", "팀장 승인"]
    },
    {
        "question": "월급은 언제 들어오나요?",
        "expected_keywords": ["25일", "영업일", "급여명세서"]
    },
    {
        "question": "재택 근무가 가능한가요?",
        "expected_keywords": ["주 2회", "슬랙", "전날 오후 6시"]
    }
]

# 간단한 평가 함수
def evaluate_answer(question, answer, expected_keywords):
    score = sum(1 for keyword in expected_keywords if keyword in answer)
    total = len(expected_keywords)
    return score, total

# %%
# 평가 실행
print(" 챗봇 성능 평가\n" + "="*50)
total_score = 0
total_keywords = 0

for eval_item in eval_data:
    # 예전: qa_chain.invoke({"query": eval_item["question"]})
    # 지금: qa_chain이 질문 문자열 하나를 받는다고 가정
    result = qa_chain.invoke(eval_item["question"])

    # 예전: result["result"]
    # 지금: result["answer"]
    answer = result["answer"]

    score, total = evaluate_answer(
        eval_item["question"],
        answer,
        eval_item["expected_keywords"]
    )

    total_score += score
    total_keywords += total

    print(f"\n질문: {eval_item['question']}")
    print(f"점수: {score}/{total} (포함된 키워드 비율)")
    print(f"답변: {answer[:100]}...")

accuracy = (total_score / total_keywords) * 100
print("\n" + "="*50)
print(f"전체 정확도: {accuracy:.1f}%")
# Out:
#  챗봇 성능 평가
# ==================================================
#
# 질문: 연차 신청은 어떻게 하나요?
# 점수: 3/4 (포함된 키워드 비율)
# 답변: 연차 신청은 사내 그룹웨어의 '전자결재' 메뉴에서 '휴가신청서'를 작성하시면 됩니다. 최소 3일 전에 신청해야 하며, 팀장의 승인이 필요합니다. 긴급한 경우에는 전화로 먼저 알리고...
#
# 질문: 월급은 언제 들어오나요?
# 점수: 3/3 (포함된 키워드 비율)
# 답변: 급여는 매월 25일에 지급됩니다. 만약 25일이 주말이나 공휴일인 경우, 그 전 영업일에 지급됩니다. 급여명세서는 급여일 오전에 이메일로 발송됩니다. 추가로 궁금한 사항이 있으시면...
#
# 질문: 재택 근무가 가능한가요?
# 점수: 3/3 (포함된 키워드 비율)
# 답변: 네, 재택근무는 가능합니다. 주 2회까지 가능하며, 전날 오후 6시까지 팀장에게 슬랙으로 신청하시면 됩니다. 재택근무 중에는 오전 10시부터 오후 5시까지 업무 가능 상태여야 하며...
#
# ==================================================
# 전체 정확도: 90.0%

# %% [markdown]
# ## Step 8: 실전 배포를 위한 추가 기능

# %%
# Gradio를 사용한 간단한 UI: https://www.gradio.app/
# !pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-6.0.2-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<25.0,>=22.0 (from gradio)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from gradio) (4.11.0)
# Collecting brotli>=1.1.0 (from gradio)
#   Downloading brotli-1.2.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.1 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.123.6-py3-none-any.whl.metadata (30 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-1.0.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==2.0.1 (from gradio)
#   Downloading gradio_client-2.0.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from gradio) (0.36.0)
# Requirement already satisfied: jinja2<4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from gradio) (2.2.6)
# Requirement already satisfied: orjson~=3.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from gradio) (3.11.4)
# Requirement already satisfied: packaging in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<13.0,>=8.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from gradio) (12.0.0)
# Requirement already satisfied: pydantic<=2.12.4,>=2.11.10 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from gradio) (2.12.4)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from gradio) (6.0.3)
# Collecting safehttpx<0.2.0,>=0.1.7 (from gradio)
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.13.3-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from gradio) (0.20.0)
# Requirement already satisfied: typing-extensions~=4.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from gradio) (0.38.0)
# Requirement already satisfied: fsspec in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from gradio-client==2.0.1->gradio) (2024.6.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from anyio<5.0,>=3.0->gradio) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Collecting annotated-doc>=0.0.2 (from fastapi<1.0,>=0.115.2->gradio)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: certifi in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.20.0)
# Requirement already satisfied: requests in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic<=2.12.4,>=2.11.10->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic<=2.12.4,>=2.11.10->gradio) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from pydantic<=2.12.4,>=2.11.10->gradio) (0.4.2)
# Requirement already satisfied: click>=8.0.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from typer<1.0,>=0.12->gradio) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from typer<1.0,>=0.12->gradio) (14.2.0)
# Requirement already satisfied: six>=1.5 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jayden86/miniconda3/envs/codeit_1/lib/python3.10/site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (2.3.0)
# Downloading gradio-6.0.2-py3-none-any.whl (21.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.6/21.6 MB 28.1 MB/s  0:00:00m0:00:0100:01
# Downloading gradio_client-2.0.1-py3-none-any.whl (55 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading fastapi-0.123.6-py3-none-any.whl (111 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
# Downloading tomlkit-0.13.3-py3-none-any.whl (38 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading brotli-1.2.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.7 MB/s  0:00:00
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ffmpy-1.0.0-py3-none-any.whl (5.6 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub, brotli, tomlkit, semantic-version, python-multipart, groovy, ffmpy, annotated-doc, aiofiles, starlette, safehttpx, gradio-client, fastapi, gradio
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/14 [gradio]13/14 [gradio]]
# Successfully installed aiofiles-24.1.0 annotated-doc-0.0.4 brotli-1.2.0 fastapi-0.123.6 ffmpy-1.0.0 gradio-6.0.2 gradio-client-2.0.1 groovy-0.1.2 pydub-0.25.1 python-multipart-0.0.20 safehttpx-0.1.7 semantic-version-2.10.0 starlette-0.50.0 tomlkit-0.13.3

# %%
import gradio as gr

def chatbot_interface(message, history):
    """Gradio 챗봇 인터페이스"""
    # 질문 문자열 하나만 넣기
    result = qa_chain.invoke(message)

    answer = result["answer"]

    # 참고 문서에서 FAQ 질문 타이틀 뽑기
    sources = [
        doc.metadata.get("question", "N/A")
        for doc in result.get("source_documents", [])
    ]

    if sources:
        answer += "\n\n📚 참고한 FAQ:\n" + "\n".join(
            [f"- {s}" for s in sources[:2]]
        )

    return answer

demo = gr.ChatInterface(
    fn=chatbot_interface,
    title="🏢 HR FAQ 챗봇",
    description="회사 HR 관련 질문을 해보세요!",
    examples=[
        "연차는 어떻게 신청하나요?",
        "급여일이 언제인가요?",
        "재택근무가 가능한가요?",
        "건강검진은 언제 받나요?"
    ]
)

demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://035d3571e1e28d3f5b.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://035d3571e1e28d3f5b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## 추가 학습 자료
#
# 1. **LangChain 공식 문서**: https://python.langchain.com/
# 2. **LangSmith 가이드**: https://docs.smith.langchain.com/
# 3. **RAG 심화**: https://python.langchain.com/docs/use_cases/question_answering/
# 4. **프롬프트 엔지니어링**: https://www.promptingguide.ai/
