# %% [markdown]
# # 텍스트 전처리
# 1. 토큰화
# 2. 텍스트 정제
# 3. 형태소 분석 및 품사 태깅
# 4. 바이트페어 변환

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/data/nreview_mask.csv")
df.head()
# Out:
#          id       date                                               text  rat
# 0  euge****  22.09.16.  새부리 KF94 마스크를 검색하니 네이버 랭킹 상위에 뜨고 가격도 착해서 호기심에 ...  평점5
# 1  gemm****  22.05.03.  컬러 KF94 마스크를 너무나도 기다렸어요\n예쁜 컬러에 벌크포장과 저렴하면서 퀄리...  평점5
# 2  gemm****  22.05.06.  컬러 KF94 마스크를 너무나도 기다렸어요\n세상 어디에도 없는 라이트실버 H워월V...  평점5
# 3  jina****  22.07.22.  라이브 보고 방송하는언니 쓴거 넘 예뻐서 100개 주문했는데 가로사이즈가 저한테 좀...  평점5
# 4  pim4****  22.10.21.  고민고민하다 디럭스 실버를 주문했는데\n진짜 이쁩니다. 과하지 않지만 평범하지도 않...  평점5

# %% [markdown]
# ## 1. 토큰화
#
# 사람이 텍스트를 이해 할 때는 문장 안의 단어를 보며 문장을 파악하고 이해를 합니다. 컴퓨터 또한 텍스트를 분석하기 위해서는 텍스트를 특정 의미 단위로 분할하여 문장을 파악할수 있게 합니다. 이러한 의미 단위을 토큰이라고 합니다.
#
# ### 문자로 토큰화
#
# 토큰화 방식중 가장 간단하게 접근하는 방식은 띄어쓰기를 기준으로 단어를 구분 하는 것입니다. 파이썬에서는 split() 함수를 이용하면 쉽게 토큰화가 가능합니다.

# %%
text = df.loc[0, "text"]
text
# Out:
# '새부리 KF94 마스크를 검색하니 네이버 랭킹 상위에 뜨고 가격도 착해서 호기심에 주문해봤어요\n특히 핑크베이지 색상이 예뻐보여서요\n무난하게 맨날 화이트 블랙만 사보고 핑크 계열은 안사봐서 궁금하기도 하고 무엇보다 가격이 메리트가 커서 ㅋㅋ\n장바구니에 담을 때 분명 9,900원이었는데 결제하려고 보니까 12,900원 뜨더라구요? 그래서 주문 못하고 있다가 하루에도 라이브를 몇 번 씩 하시고 그 타이밍에 주문하면 9,900원이라 운좋게 아침 8시반 라방하기 전 8시에 주문 성공해서 당일 출고해서 담날 바로 받았어요\n봄 여름 핑크가 아니라 딱 가을 겨울 톤다운 핑크예요~\n살구핑크베이지랄까? 차분한 톤이라 오히려 맘에 드네요\n다른 후기처럼 중형인데 일반 대형 사이즈라길래 중형으로 주문했더니 역시나 넉넉하게 잘 맞아요\n남편이 써도 잘 맞더라구요\n웬만한 보통 얼굴 크기 남성이라면 중형도 OK일듯!\n가로폭이 커서 얼굴 전체를 잘 감싸주고 세로는 약간 짧은듯한데 그렇다고 부족하진 않아요\n사진에 미밋 대형, 아이랑 어른용과 비교 사이즈 남겼으니 참고 부탁드려요\n일단 25매 벌크 포장 뜯었을 때는 딱히 불량이 안보이고 괜찮은데 제발 한달 사용 후기로 평범 1점 주는 일이 없기를 바래야겠어요\n암튼 가성비 마스크로 추천!'

# %%
text = text.split(' ')
print(text)
# Out:
# ['새부리', 'KF94', '마스크를', '검색하니', '네이버', '랭킹', '상위에', '뜨고', '가격도', '착해서', '호기심에', '주문해봤어요\n특히', '핑크베이지', '색상이', '예뻐보여서요\n무난하게', '맨날', '화이트', '블랙만', '사보고', '핑크', '계열은', '안사봐서', '궁금하기도', '하고', '무엇보다', '가격이', '메리트가', '커서', 'ㅋㅋ\n장바구니에', '담을', '때', '분명', '9,900원이었는데', '결제하려고', '보니까', '12,900원', '뜨더라구요?', '그래서', '주문', '못하고', '있다가', '하루에도', '라이브를', '몇', '번', '씩', '하시고', '그', '타이밍에', '주문하면', '9,900원이라', '운좋게', '아침', '8시반', '라방하기', '전', '8시에', '주문', '성공해서', '당일', '출고해서', '담날', '바로', '받았어요\n봄', '여름', '핑크가', '아니라', '딱', '가을', '겨울', '톤다운', '핑크예요~\n살구핑크베이지랄까?', '차분한', '톤이라', '오히려', '맘에', '드네요\n다른', '후기처럼', '중형인데', '일반', '대형', '사이즈라길래', '중형으로', '주문했더니', '역시나', '넉넉하게', '잘', '맞아요\n남편이', '써도', '잘', '맞더라구요\n웬만한', '보통', '얼굴', '크기', '남성이라면', '중형도', 'OK일듯!\n가로폭이', '커서', '얼굴', '전체를', '잘', '감싸주고', '세로는', '약간', '짧은듯한데', '그렇다고', '부족하진', '않아요\n사진에', '미밋', '대형,', '아이랑', '어른용과', '비교', '사이즈', '남겼으니', '참고', '부탁드려요\n일단', '25매', '벌크', '포장', '뜯었을', '때는', '딱히', '불량이', '안보이고', '괜찮은데', '제발', '한달', '사용', '후기로', '평범', '1점', '주는', '일이', '없기를', '바래야겠어요\n암튼', '가성비', '마스크로', '추천!']

# %% [markdown]
# ### 숫자 인코딩 --> 벡터화
#
# 토큰화 이후 컴퓨터가 이를 분석 하기 위해선 문자로 나타나는 토큰을 벡터형태의 데이터로 바꾸어 주어야 합니다.
# 토큰을 여러 숫자의 조합인 벡터로 최종 변환하기 이전에 토큰에 고유한 숫자를 부여하여 인코딩 과정을 선행 해주어야 합니다.
# *토큰화 => 숫자 인코딩 => 백터화*
#
# - **인코딩**: 문자 토큰을 숫자 토큰으로 변환
# - **디코딩**: 숫자 토큰을 문자 토큰으로 변환
#
# 기본적인 인코딩 방식은 모든 문자 토큰을 찾아 고유 번호를 맵핑시킨 **딕셔너리**를 만드는 방식입니다.

# %%
uq = set()      # 고유 토큰을 하기위해서 set
for text in df['text']:
    sp = text.split(' ')
    for w in sp:
        uq.add(w)
print(uq)
# Out:
# {'쓸게용', '행복합니다', '사유로도', '개별포장되어있지', '흘러내린다는', '방송이나', '지나쳤는데..\n이번엔', 'Kf94라서', '예쁘지는', '쓸예정입니다!\n궁금함', '급주문을~가격도', '중입니다^^', '!!\n오자마자', '남편을', '작게나왔데서', '쌩눈으로', '사이즈라', '흔치', '되는게', '장점은', '어쩌나~했는데\n냄새도', '최고.', '비슷한데.', '크더라구요ㅠ\n하지만', '핑베!', '찌그러지고', '중형쓰고', '폭좁은', '편/갸름한', '민감한분은', '그레이색은4계절사용해도좋구여', '외출할때마다', '정착입니당', '사용해봤지만,', '이미', '있어요.두께감도', '컬러고민했는데', '가름하게', '께도', '살고', '잘묻어나요.', '잘못사서', '대형이다보니', '느낌이예요.', '불량인걸', '가성비론', '50매+50매', '매우매우', '피부가', '사이즈의', '얼큰이라', '얼굴공개는', '감싸주는것도', '늘려보았는데ㅜㅜ', '도착!!', '이모도', '2개나', '예뻐요.\n겨울이다보니', '안덥다', '쓸까요~~아놔~~', '넙데데해보임.', '아플', '편한데\nkf94', '핑크디럭스소형\n\n겹쳐서', '제품이면', '얊은편은', '아님.)그래서', '자신있게', '2백원도', '아니였어요!\n그레이는', '같이쓸라고', '중점입니다:)', '비움스타일핏', '기온이', '사이즈는크고', '가격할인이', '좋았을거', '나왔다기에', '관한', '밀착되는것도', '썼는데요...\n전', '구석에', '추천합니다.\n\n그리고', '벌크형도', '재구매한거지만;;;', 'X로', '비슷', '반나절정도만', '찰떡이에요', '들어요.\n\n얼굴이', '핑베가', '벌리자마자', '드는거', '더욱', '구레나룻까지', '구매했어요🙋\u200d♀️', '마저도', ',안쓴다고하더라구요ㅠ비움', '비슷한거', '어려웠어요.', '봄여름', '잡아주네요!', '시원해보인다고했는데', '징징거려', '높이있는편이라', '아이백을', '해두면', '못움직이게', '편해ㅎ', '집착했었는데', '살짯', '들뜨거나', '이뻐요.\n넘', '점차', '스몰과', '신기해서', '뭔가가', '나눠주고', '아이보리하세요:)', '얇긴', '불량이거나..이런', '후론', '아이보리를', '쑬거', '면처럼부드럽고좋네요.\n에코브리즈', '테스트까지하고', '끝에', '주문했으나', '작게나와서', '라이트실버?', '찌그러져있고', '당근으로', '감사합니다\n반면', '찾아다녔습니다...', '배경색과', '아쉽네요\n색상은', '있게', '알았어요..\n많이', '하나로도', '떨어지네요…..너무', '같아요\n아직', '넉넉합니다..!', '느낌정도?', '같습니다!\n가격도', '좋았는데ㅜㅜ', '이제야나온건가요💗', '않고', '디럭스는..부드럽고', '달걀형이여야', '찍어놨는데', '모두다', '않았어요~\n\n+아이한테', '한사이즈작게사도', '국대소형', '드네요~^^', '규매했어요\n라이브쇼핑으로', '더워지면서', '맞는것뿐만아니라', '제품입니다.)\n우연히', '내려온단', '케이스(납작한', '이것샀는데', '운동하실', '튀지않는(', '수요일에', '완료.\n\n배송', '날히가', '수줍어지는', '취저💖\n예쁜', '심하거니', '더작은', '교환했어요~~\n중형도', '생각했지', '맞아요~대형은', '결과...', '밀착이잘되어야', '모르지만', '내부공간도맘에들어요\n좀크다는얘기가있어서', '맞는데도', '이브랜드만', '몇개씩만', '톤도', '출퇴근용으로', '구매했어요\n완젼편하게', '크답니다.', '벌어지기', '크더라구요.\n좀', '25년까지', '쟁이는지ㅜ', '다른분들도', '변함없습니다.\n아주', '부끄럽지만', '비슷해서', '차이있고', '흰색처럼보여요.색상참고하세요.', '아이껀데', '제품이엇는데', '월요일에', '넣고', '불쾌하고', '구매완료!!!\n\n예민한', '믿고,', '좋을것같아요', '턱살있는', '않아요\n3.', '맞았는데...', '되레', '광대부각이', '안아팠어요!', '두껀느낌도', '일반여자', '접착된', '코랄핑크입니다.', '안아퍼용.', '쟁여놓으세요\n여태', '보며', '해줄게요~', '사진에서는', '성인여자구요~', '끈은', '구매했는데요', '사무실에', '연하구요', '보여드립니다.', '고려하여', '의심이', '파임이', '연결된', '시작하고,', '지금처럼', '쓰려고요.', 'kf94마스크를', '후에~', '부드럽고,잘맞네요', '구매했습니다😊', '구매이네요.', '너무크고', '밀착되지않아', '아이보리로', '있습니다~^^', '착용했어서', '예뻐요@얼굴', '선택할', '열이', '아들', 'x로', '트러블도', '작아보이는건', '날들', '배송비를', '골라쓰는', '걸리는건가......\n사진찍어서', '써보자', '유목민을', 'S보다는', 'ㅜ\n비움', '20개?', '들어올때되면', '그보다', '블랙만....봄,여름에는', '긴만큼', '좋아요\n다음', '드네요\n다른', '지겹다', '62호', '애용하는', '있어요~^^', '꽉', '차이가있는지는', '젤', '튼튼하고', '있지만', '안아파요!!타사제품은', '쓸께요\n두께감이', '봅니다.\n디자인은', '주위에', '만족해요', '덜보여', '1봉짜리', '불편하거든요.....\n어머니가', '레몬색이에요.', '꺼려', '포장해', '곳이네요\n대형', '있고요~\n라이브', '잘샀네요~~~\n김태희꺼', '선물하고있어요~\n예쁘다고', '쇼핑라이브하길래', '입니다~', 'ms가', '들었어요!', '맞네요.\n근데', '사준것도', '구매했어요.\n1학년', '많은데,', '광대뼈', '남편이', '붙여두고', '튼튼하네요', '작아요..\n편하게', '디자인이라', '컬리티도', '합니다.\n아이보린', '쓰곤있지만', '잡아주시는', '사이즈네요\n중등,얼작', '안맞아서', '비교샷인데요!\n핑크,', '비슷하네요~생각보다', '안경끼고', '허허', '뺄까하다', '반풍할지', '입니다\n그레이가', '4중필터고', '뜬다고', '소분되었더라면', '완전만족이요\n생각보다', '독감.', '비움\n큰딸과', '행사보이면', '맞아도', '쓰겠습니다~~', '성능을', '해요\n한', '써질지는', '예전보다', '싶었다가', '스타일', '호흡이', '대충쓰면되지가', '피치빛', '중형으로도', '참고하셔야될것', '세로쪽이', '디자인에\n컬러도', '젊은', '에코플러스', '덜타고\n마스크', '같아요.\n좋은', '바꾸세요.\n핑크베이지', '사용합니다.\n색감도', '끊어지려고', '두껍진', '속상하네요..\n94인데도', '커보입니다\n중형은', '모든분들이', 'ㅡ다른', '불편하진', '브랜드에요!!', '주문할게요~', '하복마스크로', '여리여리베이지느낌은', '에코브리즈쓰다가', '핑크골드라기', '필요해보이네요...ㅎㅎ', '못느낄것', '말고', '뜯으라고', '디럭스대형으로', '사봤는데\n착용감도', '70원씩인지', '얇은마스크를', '너~무', '감기처럼', '감싸주는', '구렛나루부분까지', '난다', '맞추지말고', '사용했습니다', '벌크가', '2020년', '직접써보니', '.\n추가', '좋네요~♡\n\ntip:', '괜찮네요\n어른은', '아이보리까지', '3천원씩', '가장마음에들어요💕💕', '컸어요', '찌그러져왔고요\nM50', '저렴해요', '아이보리쓰니까', '줄어서', '장마철인', '차요', '예방에도', '제품으로', '붙어있고', '좀커요.', '군말없이', '얼굴사이즈', '모르겠지만,', '얇구요~\n근데', '정착..\n다음에는', '붙어있어서', '순간..아', '슬프네요..ㅠㅠ', '언젠가', '선선해', '두면', '고르지얺아요!', '너어무', '제작문제가', '에코프로와', '마스크늠', '했네요...디럭스', '빠르고,', '중형사서', '사 ...

# %%
enc_dict = {}           # dict, list 필수 교육
for i, t in enumerate(uq):
    enc_dict[t] = i
print(enc_dict)
# Out:
# {'쓸게용': 0, '행복합니다': 1, '사유로도': 2, '개별포장되어있지': 3, '흘러내린다는': 4, '방송이나': 5, '지나쳤는데..\n이번엔': 6, 'Kf94라서': 7, '예쁘지는': 8, '쓸예정입니다!\n궁금함': 9, '급주문을~가격도': 10, '중입니다^^': 11, '!!\n오자마자': 12, '남편을': 13, '작게나왔데서': 14, '쌩눈으로': 15, '사이즈라': 16, '흔치': 17, '되는게': 18, '장점은': 19, '어쩌나~했는데\n냄새도': 20, '최고.': 21, '비슷한데.': 22, '크더라구요ㅠ\n하지만': 23, '핑베!': 24, '찌그러지고': 25, '중형쓰고': 26, '폭좁은': 27, '편/갸름한': 28, '민감한분은': 29, '그레이색은4계절사용해도좋구여': 30, '외출할때마다': 31, '정착입니당': 32, '사용해봤지만,': 33, '이미': 34, '있어요.두께감도': 35, '컬러고민했는데': 36, '가름하게': 37, '께도': 38, '살고': 39, '잘묻어나요.': 40, '잘못사서': 41, '대형이다보니': 42, '느낌이예요.': 43, '불량인걸': 44, '가성비론': 45, '50매+50매': 46, '매우매우': 47, '피부가': 48, '사이즈의': 49, '얼큰이라': 50, '얼굴공개는': 51, '감싸주는것도': 52, '늘려보았는데ㅜㅜ': 53, '도착!!': 54, '이모도': 55, '2개나': 56, '예뻐요.\n겨울이다보니': 57, '안덥다': 58, '쓸까요~~아놔~~': 59, '넙데데해보임.': 60, '아플': 61, '편한데\nkf94': 62, '핑크디럭스소형\n\n겹쳐서': 63, '제품이면': 64, '얊은편은': 65, '아님.)그래서': 66, '자신있게': 67, '2백원도': 68, '아니였어요!\n그레이는': 69, '같이쓸라고': 70, '중점입니다:)': 71, '비움스타일핏': 72, '기온이': 73, '사이즈는크고': 74, '가격할인이': 75, '좋았을거': 76, '나왔다기에': 77, '관한': 78, '밀착되는것도': 79, '썼는데요...\n전': 80, '구석에': 81, '추천합니다.\n\n그리고': 82, '벌크형도': 83, '재구매한거지만;;;': 84, 'X로': 85, '비슷': 86, '반나절정도만': 87, '찰떡이에요': 88, '들어요.\n\n얼굴이': 89, '핑베가': 90, '벌리자마자': 91, '드는거': 92, '더욱': 93, '구레나룻까지': 94, '구매했어요🙋\u200d♀️': 95, '마저도': 96, ',안쓴다고하더라구요ㅠ비움': 97, '비슷한거': 98, '어려웠어요.': 99, '봄여름': 100, '잡아주네요!': 101, '시원해보인다고했는데': 102, '징징거려': 103, '높이있는편이라': 104, '아이백을': 105, '해두면': 106, '못움직이게': 107, '편해ㅎ': 108, '집착했었는데': 109, '살짯': 110, '들뜨거나': 111, '이뻐요.\n넘': 112, '점차': 113, '스몰과': 114, '신기해서': 115, '뭔가가': 116, '나눠주고': 117, '아이보리하세요:)': 118, '얇긴': 119, '불량이거나..이런': 120, '후론': 121, '아이보리를': 122, '쑬거': 123, '면처럼부드럽고좋네요.\n에코브리즈': 124, '테스트까지하고': 125, '끝에': 126, '주문했으나': 127, '작게나와서': 128, '라이트실버?': 129, '찌그러져있고': 130, '당근으로': 131, '감사합니다\n반면': 132, '찾아다녔습니다...': 133, '배경색과': 134, '아쉽네요\n색상은': 135, '있게': 136, '알았어요..\n많이': 137, '하나로도': 138, '떨어지네요…..너무': 139, '같아요\n아직': 140, '넉넉합니다..!': 141, '느낌정도?': 142, '같습니다!\n가격도': 143, '좋았는데ㅜㅜ': 144, '이제야나온건가요💗': 145, '않고': 146, '디럭스는..부드럽고': 147, '달걀형이여야': 148, '찍어놨는데': 149, '모두다': 150, '않았어요~\n\n+아이한테': 151, '한사이즈작게사도': 152, '국대소형': 153, '드네요~^^': 154, '규매했어요\n라이브쇼핑으로': 155, '더워지면서': 156, '맞는것뿐만아니라': 157, '제품입니다.)\n우연히': 158, '내려온단': 159, '케이스(납작한': 160, '이것샀는데': 161, '운동하실': 162, '튀지않는(': 163, '수요일에': 164, '완료.\n\n배송': 165, '날히가': 166, '수줍어지는': 167, '취저💖\n예쁜': 168, '심하거니': 169, '더작은': 170, '교환했어요~~\n중형도': 171, '생각했지': 172, '맞아요~대형은': 173, '결과...': 174, '밀착이잘되어야': 175, '모르지만': 176, '내부공간도맘에들어요\n좀크다는얘기가있어서': 177, '맞는데도': 178, '이브랜드만': 179, '몇개씩만': 180, '톤도': 181, '출퇴근용으로': 182, '구매했어요\n완젼편하게': 183, '크답니다.': 184, '벌어지기': 185, '크더라구요.\n좀': 186, '25년까지': 187, '쟁이는지ㅜ': 188, '다른분들도': 189, '변함없습니다.\n아주': 190, '부끄럽지만': 191, '비슷해서': 192, '차이있고': 193, '흰색처럼보여요.색상참고하세요.': 194, '아이껀데': 195, '제품이엇는데': 196, '월요일에': 197, '넣고': 198, '불쾌하고': 199, '구매완료!!!\n\n예민한': 200, '믿고,': 201, '좋을것같아요': 202, '턱살있는': 203, '않아요\n3.': 204, '맞았는데...': 205, '되레': 206, '광대부각이': 207, '안아팠어요!': 208, '두껀느낌도': 209, '일반여자': 210, '접착된': 211, '코랄핑크입니다.': 212, '안아퍼용.': 213, '쟁여놓으세요\n여태': 214, '보며': 215, '해줄게요~': 216, '사진에서는': 217, '성인여자구요~': 218, '끈은': 219, '구매했는데요': 220, '사무실에': 221, '연하구요': 222, '보여드립니다.': 223, '고려하여': 224, '의심이': 225, '파임이': 226, '연결된': 227, '시작하고,': 228, '지금처럼': 229, '쓰려고요.': 230, 'kf94마스크를': 231, '후에~': 232, '부드럽고,잘맞네요': 233, '구매했습니다😊': 234, '구매이네요.': 235, '너무크고': 236, '밀착되지않아': 237, '아이보리로': 238, '있습니다~^^': 239, '착용했어서': 240, '예뻐요@얼굴': 241, '선택할': 242, '열이': 243, '아들': 244, 'x로': 245, '트러블도': 246, '작아보이는건': 247, '날들': 248, '배송비를': 249, '골라쓰는': 250, '걸리는건가......\n사진찍어서': 251, '써보자': 252, '유목민을': 253, 'S보다는': 254, 'ㅜ\n비움': 255, '20개?': 256, '들어올때되면': 257, '그보다': 258, '블랙만....봄,여름에는': 259, '긴만큼': 260, '좋아요\n다음': 261, '드네요\n다른': 262, '지겹다': 263, '62호': 264, '애용하는': 265, '있어요~^^': 266, '꽉': 267, '차이가있는지는': 268, '젤': 269, '튼튼하고': 270, '있지만': 271, '안아파요!!타사제품은': 272, '쓸께요\n두께감이': 273, '봅니다.\n디자인은': 274, '주위에': 275, '만족해요': 276, '덜보여': 277, '1봉짜리': 278, '불편하거든요..... ...

# %%
text = df.loc[0, 'text']
str_tk = text.split(' ')
enc_tk = [enc_dict[w] for w in str_tk]
print(str_tk)
print(enc_tk)
# Out:
# ['새부리', 'KF94', '마스크를', '검색하니', '네이버', '랭킹', '상위에', '뜨고', '가격도', '착해서', '호기심에', '주문해봤어요\n특히', '핑크베이지', '색상이', '예뻐보여서요\n무난하게', '맨날', '화이트', '블랙만', '사보고', '핑크', '계열은', '안사봐서', '궁금하기도', '하고', '무엇보다', '가격이', '메리트가', '커서', 'ㅋㅋ\n장바구니에', '담을', '때', '분명', '9,900원이었는데', '결제하려고', '보니까', '12,900원', '뜨더라구요?', '그래서', '주문', '못하고', '있다가', '하루에도', '라이브를', '몇', '번', '씩', '하시고', '그', '타이밍에', '주문하면', '9,900원이라', '운좋게', '아침', '8시반', '라방하기', '전', '8시에', '주문', '성공해서', '당일', '출고해서', '담날', '바로', '받았어요\n봄', '여름', '핑크가', '아니라', '딱', '가을', '겨울', '톤다운', '핑크예요~\n살구핑크베이지랄까?', '차분한', '톤이라', '오히려', '맘에', '드네요\n다른', '후기처럼', '중형인데', '일반', '대형', '사이즈라길래', '중형으로', '주문했더니', '역시나', '넉넉하게', '잘', '맞아요\n남편이', '써도', '잘', '맞더라구요\n웬만한', '보통', '얼굴', '크기', '남성이라면', '중형도', 'OK일듯!\n가로폭이', '커서', '얼굴', '전체를', '잘', '감싸주고', '세로는', '약간', '짧은듯한데', '그렇다고', '부족하진', '않아요\n사진에', '미밋', '대형,', '아이랑', '어른용과', '비교', '사이즈', '남겼으니', '참고', '부탁드려요\n일단', '25매', '벌크', '포장', '뜯었을', '때는', '딱히', '불량이', '안보이고', '괜찮은데', '제발', '한달', '사용', '후기로', '평범', '1점', '주는', '일이', '없기를', '바래야겠어요\n암튼', '가성비', '마스크로', '추천!']
# [17260, 1137, 19282, 16636, 19106, 23196, 12746, 2467, 28137, 9511, 2055, 13547, 15226, 30425, 15395, 16629, 12300, 21222, 31386, 16692, 5477, 22732, 29843, 2167, 2287, 9716, 14779, 28207, 15970, 13248, 13610, 9210, 25842, 711, 22722, 13990, 10183, 9188, 28796, 9589, 25610, 30432, 14989, 22870, 31844, 27359, 24062, 1433, 21195, 10981, 30065, 4544, 31473, 9868, 22428, 2076, 27120, 28796, 28731, 29183, 22685, 23550, 13852, 11525, 11590, 2946, 28183, 19012, 17065, 27423, 3653, 23777, 28471, 5810, 7138, 31506, 262, 16145, 25407, 15563, 26943, 4303, 16235, 13054, 10868, 21692, 10644, 31504, 4374, 10644, 5206, 15757, 4122, 16993, 4996, 13235, 29572, 28207, 4122, 7267, 10644, 30142, 18034, 22214, 807, 13987, 16763, 27281, 13794, 12882, 28018, 10509, 31737, 19294, 23848, 3565, 21581, 18897, 584, 5443, 1764, 14858, 19791, 3376, 902, 19426, 18607, 17892, 28992, 13614, 29965, 14973, 18486, 867, 19697, 18597, 16932, 20261, 5223]

# %% [markdown]
# ## 2. 텍스트 정제(클리닝)
#
# 기본적인 토큰화 결과 특수문자나 의미없는 단어들 또한 하나의 토큰으로 분리 되었습니다. 이러한 불필요한 토큰은 텍스트 분석에 있어 방해 요소가 됩니다.
#
# 따라서 의미 없는 기호, 단어를 제거하는 작업을 먼저 진행하는 클렌징 작업이 필요합니다.

# %%
text = df.loc[4, 'text']
text
# Out:
# '고민고민하다 디럭스 실버를 주문했는데\n진짜 이쁩니다. 과하지 않지만 평범하지도 않아 좋아요. 어두운 옷, 밝은 옷에도 쓰기 좋네요. 큰 얼굴이지만 디럭스 사이즈는 여유있게 편하고 씁니다. 꽉 끼는 불편함이 없어서 맘에 들어요.\n지인한테 써보라고 자신있게 1봉 나눔했어요~^^\n구매평 중 많았던 연결부위 끈 떨어짐 현상은 아직 없었어서 좋아라 했는데,\n몇일전 아침에 쓸려고 보니 끈 한쪽의 반이 잘려 나간 듯이 짧았어요. 살펴보니 다행이 하나만 그러네요.\n불량이 하필 실버 색상에서 나와서 그게 아쉬워요. 다른 색상 마스크 였다면 좋았을 텐데ㅠㅠ\n유색마스크는 좀 비싸던데, 가격대비 제품이 좋아서 만족도가 좋았어요.\n그래도 다음에는 불량체크 잘 된 제품으로 꼭받고 싶어요.\n흰색, 검정색 지겹고, 과한 색상은 부담이신분들께 조심스럽게 실버마스크 추천합니다.'

# %% [markdown]
# ### 특수 문자 제거하기
#
# 특수 문자 제거는 파이썬 내장 모듈인 `re`모듈을 사용합니다
# > re.sub(수정될 문자열의 정규식, 수정후의 문자열, 문자열)
#
# \w: A–Z, a–z, 0–9, _

# %%
import re

rtext = re.sub(r'[^\w\s]', '', text)    # 숫자(\w), 공백(\s)을 제외한 모든 특수문자 제거
rtext = re.sub(r'[\n\t]', ' ', rtext)   # 줄바꿈(\n), 탭(\t) 제거
rtext = re.sub(r'\s+', ' ', rtext)      # 연속된 공백(\s+) 제거
rtext
# Out:
# '고민고민하다 디럭스 실버를 주문했는데 진짜 이쁩니다 과하지 않지만 평범하지도 않아 좋아요 어두운 옷 밝은 옷에도 쓰기 좋네요 큰 얼굴이지만 디럭스 사이즈는 여유있게 편하고 씁니다 꽉 끼는 불편함이 없어서 맘에 들어요 지인한테 써보라고 자신있게 1봉 나눔했어요 구매평 중 많았던 연결부위 끈 떨어짐 현상은 아직 없었어서 좋아라 했는데 몇일전 아침에 쓸려고 보니 끈 한쪽의 반이 잘려 나간 듯이 짧았어요 살펴보니 다행이 하나만 그러네요 불량이 하필 실버 색상에서 나와서 그게 아쉬워요 다른 색상 마스크 였다면 좋았을 텐데ㅠㅠ 유색마스크는 좀 비싸던데 가격대비 제품이 좋아서 만족도가 좋았어요 그래도 다음에는 불량체크 잘 된 제품으로 꼭받고 싶어요 흰색 검정색 지겹고 과한 색상은 부담이신분들께 조심스럽게 실버마스크 추천합니다'

# %% [markdown]
# ### 불용어 제거
#
# 불용어 제거는 파이썬의 문자열 함수와 리스트, 반복문등을 이용하여 구성 가능합니다.
# 먼저 토큰화 이후 반복문을 통해서 해당 단어가 불용어에 속하는지 `if` `in` 문을 활용하여 체크하고 속하지 않으면 새로운 리스트에 담아 `join`해줍니다.

# %%
print(rtext.split(' '))
# Out:
# ['고민고민하다', '디럭스', '실버를', '주문했는데', '진짜', '이쁩니다', '과하지', '않지만', '평범하지도', '않아', '좋아요', '어두운', '옷', '밝은', '옷에도', '쓰기', '좋네요', '큰', '얼굴이지만', '디럭스', '사이즈는', '여유있게', '편하고', '씁니다', '꽉', '끼는', '불편함이', '없어서', '맘에', '들어요', '지인한테', '써보라고', '자신있게', '1봉', '나눔했어요', '구매평', '중', '많았던', '연결부위', '끈', '떨어짐', '현상은', '아직', '없었어서', '좋아라', '했는데', '몇일전', '아침에', '쓸려고', '보니', '끈', '한쪽의', '반이', '잘려', '나간', '듯이', '짧았어요', '살펴보니', '다행이', '하나만', '그러네요', '불량이', '하필', '실버', '색상에서', '나와서', '그게', '아쉬워요', '다른', '색상', '마스크', '였다면', '좋았을', '텐데ㅠㅠ', '유색마스크는', '좀', '비싸던데', '가격대비', '제품이', '좋아서', '만족도가', '좋았어요', '그래도', '다음에는', '불량체크', '잘', '된', '제품으로', '꼭받고', '싶어요', '흰색', '검정색', '지겹고', '과한', '색상은', '부담이신분들께', '조심스럽게', '실버마스크', '추천합니다']

# %%
sptext = rtext.split(' ')
st_words = ['진짜', '꽉']
nw = []
for w in sptext:
    if w not in st_words:
        nw.append(w)
print(nw)
# Out:
# ['고민고민하다', '디럭스', '실버를', '주문했는데', '이쁩니다', '과하지', '않지만', '평범하지도', '않아', '좋아요', '어두운', '옷', '밝은', '옷에도', '쓰기', '좋네요', '큰', '얼굴이지만', '디럭스', '사이즈는', '여유있게', '편하고', '씁니다', '끼는', '불편함이', '없어서', '맘에', '들어요', '지인한테', '써보라고', '자신있게', '1봉', '나눔했어요', '구매평', '중', '많았던', '연결부위', '끈', '떨어짐', '현상은', '아직', '없었어서', '좋아라', '했는데', '몇일전', '아침에', '쓸려고', '보니', '끈', '한쪽의', '반이', '잘려', '나간', '듯이', '짧았어요', '살펴보니', '다행이', '하나만', '그러네요', '불량이', '하필', '실버', '색상에서', '나와서', '그게', '아쉬워요', '다른', '색상', '마스크', '였다면', '좋았을', '텐데ㅠㅠ', '유색마스크는', '좀', '비싸던데', '가격대비', '제품이', '좋아서', '만족도가', '좋았어요', '그래도', '다음에는', '불량체크', '잘', '된', '제품으로', '꼭받고', '싶어요', '흰색', '검정색', '지겹고', '과한', '색상은', '부담이신분들께', '조심스럽게', '실버마스크', '추천합니다']

# %% [markdown]
# ### 전체 데이터에 클렌징 적용
#
# DataFrame 사용시 apply() 사용하여 일괄처리해줍니다

# %%
import re

stopwords = ['', '진짜', '않지만']

def cleaning(review):
    review = re.sub(r'[^\w\s]', '', review)
    review = re.sub(r'[\n\t]', ' ', review)
    review = re.sub(r'\s+', ' ', review)
    review = review.strip()

    # 불용어 제거
    review = ' '.join([w for w in review.split(' ') if w not in stopwords])
    # 한글자 제거
    review = ' '.join([w for w in review.split(' ') if len(w) > 1])

    return review

# 클렌징 함수 적용
df['clean'] = df['text'].apply(cleaning)
df[['text', 'clean']]
# Out:
#                                                    text  \
# 0     새부리 KF94 마스크를 검색하니 네이버 랭킹 상위에 뜨고 가격도 착해서 호기심에 ...
# 1     컬러 KF94 마스크를 너무나도 기다렸어요\n예쁜 컬러에 벌크포장과 저렴하면서 퀄리...
# 2     컬러 KF94 마스크를 너무나도 기다렸어요\n세상 어디에도 없는 라이트실버 H워월V...
# 3     라이브 보고 방송하는언니 쓴거 넘 예뻐서 100개 주문했는데 가로사이즈가 저한테 좀...
# 4     고민고민하다 디럭스 실버를 주문했는데\n진짜 이쁩니다. 과하지 않지만 평범하지도 않...
# ...                                                 ...
# 2175  4중구조인 거에 비해 얇아요 그리고 귀끈이 진짜 편합니다 A사는 귀는 편하나 딱맞는...
# 2176  가격 싸서 좋아요 하지만\n흰색 마스크를 제외한 컬러가 들어간 마스크는\n코 부분 ...
# 2177  우순 엄청큰 봉투가 와서 놀랏고 ㅋㅋㅋ\n마구마구 넣으신듯한... 상자에 구겨져들어...
# 2178  기존에 에코브리즈 다른 마스크보다 우선 시원하고 크기도 큼직해서 개인적으로 기미라인...
# 2179  지난번 라방때 에코브리즈 중형 사보고 가볍고 숨쉬기 편한 질감은 만족스러운데 살짝 ...
#
#                                                   clean
# 0     새부리 KF94 마스크를 검색하니 네이버 랭킹 상위에 뜨고 가격도 착해서 호기심에 ...
# 1     컬러 KF94 마스크를 너무나도 기다렸어요 예쁜 컬러에 벌크포장과 저렴하면서 퀄리티...
# 2     컬러 KF94 마스크를 너무나도 기다렸어요 세상 어디에도 없는 라이트실버 H워월V ...
# 3     라이브 보고 방송하는언니 쓴거 예뻐서 100개 주문했는데 가로사이즈가 저한테 커요ㅠ...
# 4     고민고민하다 디럭스 실버를 주문했는데 이쁩니다 과하지 평범하지도 않아 좋아요 어두운...
# ...                                                 ...
# 2175  4중구조인 거에 비해 얇아요 그리고 귀끈이 편합니다 A사는 귀는 편하나 딱맞는 느낌...
# 2176  가격 싸서 좋아요 하지만 흰색 마스크를 제외한 컬러가 들어간 마스크는 부분 안쪽이 ...
# 2177  우순 엄청큰 봉투가 와서 놀랏고 ㅋㅋㅋ 마구마구 넣으신듯한 상자에 구겨져들어가잇어 ...
# 2178  기존에 에코브리즈 다른 마스크보다 우선 시원하고 크기도 큼직해서 개인적으로 기미라인...
# 2179  지난번 라방때 에코브리즈 중형 사보고 가볍고 숨쉬기 편한 질감은 만족스러운데 살짝 ...
#
# [2180 rows x 2 columns]

# %% [markdown]
# ## (추가) 바이트페어 변환
#
# **바이트페어 변환** 은 텍스트를 바이트단위(문자)로 묶어가며 빈도 확률에 따라 최적화된 토큰셋을 만들어 냅니다.
#
#     안 + 녕 => 빈도가 많음 => 토큰O
#     안 + 녕 + 하 => 빈도가 적음 => 토큰X
#     안 + 녕 + 하 + 세 + 요 => 빈도 많음 => 토큰 O
#
# 따라서 형태소 분석과 다르게 가지고 있는 텍스트뭉치에 따라 토큰이 최적화 되어 나온다는 장점이 있습니다.

# %% [markdown]
# ### SentencePiece 모듈 활용
#
# `sentencepiece` 모듈은 바이트페어 인코딩 기능이 있는 대표적인 파이썬 라이브러리입니다.
# sentencepiece 모듈을 활용하여 다음과정을 통해 토큰화가 가능합니다.
# 1. sentencepiece 모듈에서 SentencePieceTrainer 객체를 통해 텍스트뭉치에서 토큰셋(model) 파일을 만들어냅니다.
# 2. sentencepiece 모듈의 SentencePieceProcessor객체에 생성한 토큰셋 파일을 변환기(인코더)를 만들어 냅니다.
# 3. 만든 인코더에서 encode() 함수를 활용하여 텍스트를 토큰화 합니다.
#
# [sentencepiece](https://github.com/google/sentencepiece)

# %%
import sentencepiece as spm
print(spm.__version__)
# Out:
# 0.2.1

# %% [markdown]
# ### 텍스트 뭉치 데이터를 텍스트 파일로 생성
#
# `sentencepiece`는 텍스트 파일로부터 토큰을 찾아내는 학습을 진행하기 때문에 먼저 가지고 있는 텍스트를 하나의 .txt파일에 쓰는 작업이 필요합니다.

# %%
import sentencepiece as spm
import pandas as pd
import re

df = pd.read_csv('/content/drive/MyDrive/data/nreview_mask.csv')

# 추가 쓰기모드로 텍스트 파일 열기
with open('nreview_mask.txt', 'a', encoding='utf-8') as f:
    for text in df['text']:
        text = str(text)
        text = re.sub(r'[^\w\s]', '', text)  # 특수문자 제거
        text = re.sub(r'[\n\t]', ' ', text)  # 줄바꿈, 탭 제거
        text = re.sub(r'\s+', ' ', text)  # 연속된 공백 제거
        text= text.strip() # 문장 양끝 공백 제거
        try:
            f.write(text+'\n')
        except:
            pass

# %% [markdown]
# ### 텍스트 파일로부터 토큰 사전 및 sentencepiece 모델 작성
#
# `SentencePieceTrainer` `train()`
# * `input`: 텍스트 뭉치 파일 경로
# * `model_prefix`: 출력 모델 파일 경로
# * `vocab_size`: 찾아낼 총 토큰 개수(가지고 있는 텍스트 양에 따라 결정)

# %%
import os

# 저장 경로 생성
os.makedirs('./model', exist_ok=True)

spm.SentencePieceTrainer.train(
    input='nreview_mask.txt',       # 텍스트 뭉치 파일
    model_prefix='./model/spm',     # 출력 모델 파일 이름
    vocab_size=2000                 # 토큰 개수
)

# %% [markdown]
# ### sentencepiece 모델을 활용하여 토큰화
#
# sentencepiece 모델이 만들어진 후, `SentencePieceProcessor` 객체를 통해 생성된 모델을 다시 프로그램에 로드합니다. 이후 `encode()` 함수를 사용하여 토큰화 합니다
# * 0번 토큰은 학습되지 않은 토큰으로 설정

# %%
df.loc[3, 'text']
# Out:
# '라이브 보고 방송하는언니 쓴거 넘 예뻐서 100개 주문했는데 가로사이즈가 저한테 좀 커요ㅠㅠ\n두번째 사진은 볼부분을 밀착시키기위해 코와이어를 접어봤어용ㅋㅋ\n블로그나 리뷰,길거리를 다녀도 저렇게 쓰는사람 굉장히 많더라구요ㅠㅠ\n잘못된 마스크 쓰는법이에요\n코 접히는 부분은 최대한 콧등에 붙혀서 쓰세요ㅠㅠ\n저렇게 쓰면 마스크가 뭔 소용인가용?\n콧등에 붙히고 볼부분이 밀착이 안되면 마스크가 큰거라고 생각합니당\n아무튼 중형인데도 커서 넘 아쉽지만....ㅠ\n끈을 묶어쓰면 괜찮아서 귀찮지만 묶어서 써야겠네용\n색상이나 촉감은 넘 좋아요\n얼굴 닿는 안감도 부들부들~~\n공장냄새(?)도 안나고 마스크 자체 디자인도 넘 예뻐요!!!\n지금 이 중형보다 조금 작은 사이즈가 나왔으면 하는 바램...!!!'

# %%
import sentencepiece as spm
import pandas as pd
import re

sp = spm.SentencePieceProcessor(model_file='./model/spm.model')
df = pd.read_csv("/content/drive/MyDrive/data/nreview_mask.csv")
text = df.loc[3, 'text']
print(sp.encode(text, out_type=str))
print(sp.encode(text, out_type=int))
# Out:
# ['▁라이브', '▁보고', '▁방송', '하는', '언', '니', '▁', '쓴', '거', '▁넘', '▁예뻐서', '▁100', '개', '▁주문했는데', '▁가로', '사이즈가', '▁저한테', '▁좀', '▁커요', 'ᅲᅲ', '▁두', '번째', '▁사진', '은', '▁볼', '부분', '을', '▁밀착', '시', '키', '기', '위', '해', '▁코', '와', '이', '어', '를', '▁', '접', '어', '봤', '어', '용', 'ᄏᄏ', '▁', '블', '로', '그', '나', '▁리뷰', ',', '길', '거', '리', '를', '▁다', '녀', '도', '▁저', '렇', '게', '▁쓰는', '사', '람', '▁', '굉', '장', '히', '▁많', '더라구요', 'ᅲᅲ', '▁잘', '못', '된', '▁마스크', '▁쓰는', '법', '이에요', '▁코', '▁', '접', '히', '는', '▁부분', '은', '▁', '최', '대', '한', '▁', '콧', '등', '에', '▁붙', '혀', '서', '▁쓰', '세요', 'ᅲᅲ', '▁저', '렇', '게', '▁쓰면', '▁마스크가', '▁', '뭔', '▁소', '용', '인', '가', '용', '?', '▁', '콧', '등', '에', '▁붙', '히', '고', '▁볼', '부분이', '▁밀착', '이', '▁안되', '면', '▁마스크가', '▁큰', '거라', '고', '▁생각', '합', '니', '당', '▁아무', '튼', '▁중형인데', '도', '▁커서', '▁넘', '▁아', '쉽', '지만', '....', 'ᅲ', '▁끈을', '▁', '묶', '어', '쓰면', '▁괜찮', '아서', '▁귀', '찮', '지만', '▁묶어서', '▁써야', '겠', '네', '용', '▁색상이', '나', '▁', '촉', '감', '은', '▁넘', '▁좋아요', '▁얼굴', '▁닿는', '▁안감', '도', '▁부', '들', '부', '들', '~~', '▁', '공', '장', '냄', '새', '(?)', '도', '▁안', '나', '고', '▁마스크', '▁자체', '▁디자인', '도', '▁넘', '▁예뻐요', '!!!', '▁지금', '▁', '이', '▁중형', '보다', '▁조금', '▁작은', '▁사이즈가', '▁나왔', '으면', '▁', '하는', '▁바', '램', '...!!!']
# [211, 525, 301, 151, 1296, 83, 3, 989, 24, 127, 893, 425, 63, 574, 387, 922, 973, 25, 503, 340, 250, 670, 128, 8, 279, 314, 15, 380, 78, 523, 29, 514, 62, 179, 105, 4, 32, 53, 3, 784, 32, 234, 32, 139, 352, 3, 1290, 21, 305, 34, 420, 0, 172, 24, 56, 53, 41, 1280, 5, 108, 1989, 17, 443, 114, 1980, 3, 1920, 145, 42, 473, 146, 340, 16, 1988, 207, 12, 443, 1505, 287, 179, 3, 784, 42, 6, 456, 8, 3, 1968, 144, 22, 3, 1942, 576, 10, 823, 1047, 11, 192, 700, 340, 108, 1989, 17, 285, 131, 3, 1956, 580, 139, 46, 7, 139, 0, 3, 1942, 576, 10, 823, 42, 9, 279, 455, 380, 4, 685, 28, 131, 92, 917, 9, 206, 1063, 83, 298, 634, 649, 835, 5, 181, 127, 122, 1977, 43, 0, 187, 719, 3, 1984, 32, 972, 397, 260, 107, 1087, 43, 631, 934, 429, 853, 139, 283, 34, 3, 1891, 163, 8, 127, 51, 39, 994, 724, 5, 512, 48, 325, 48, 0, 3, 439, 145, 1349, 545, 0, 5, 35, 34, 9, 12, 1245, 275, 5, 127, 227, 0, 421, 3, 4, 30, 58, 73, 136, 164, 453, 155, 3, 151, 346, 1413, 0]

# %% [markdown]
# > spm를 활용한 바이트페어 토큰화 결과중 `_`는 기존 문장의 띄어쓰기를 의미합니다
# > 띄어쓰기로 join하여도 기본 문장의 띄어쓰기 정보를 읽어버리지 않습니다.

# %% [markdown]
# ### 특수 토큰을 추가
#
# `bos_id`:문장의 시작을 알리는 토큰 번호
# `eos_id`:문장의 끝을 알리느 토큰 번호
# `unk_id`:학습되지 않은 토큰 번호
# `pad_id`: 패딩 토큰 번호(무시 토큰)

# %%
spm.SentencePieceTrainer.train(input='nreview_mask.txt',      # 텍스트 뭉치 파일
                            model_prefix='./model/spm',       # 출력 모델 파일 이름
                            vocab_size=4000,                  # 토큰 개수
                            bos_id=1,
                            eos_id=2,
                            unk_id=0,
                            pad_id=3
                            )

# %%
sp = spm.SentencePieceProcessor(model_file='./model/spm.model') # 모델 로드
df = pd.read_csv("/content/drive/MyDrive/data/nreview_mask.csv")

text = df.loc[3, 'text']
for line in text.split('\n'):
    print(sp.encode(line, out_type=str))
    print([sp.bos_id()] + sp.encode(line, out_type=int) + [sp.eos_id()])
# Out:
# ['▁라이브', '▁보고', '▁방송', '하는', '언', '니', '▁쓴', '거', '▁넘', '▁예뻐서', '▁100', '개', '▁주문했는데', '▁가로', '사이즈가', '▁저한테', '▁좀', '▁커요', 'ᅲᅲ']
# [1, 158, 313, 289, 219, 1707, 60, 889, 56, 83, 665, 290, 88, 411, 400, 825, 666, 21, 365, 354, 2]
# ['▁두번째', '▁사진', '은', '▁볼부분', '을', '▁밀착', '시', '키', '기', '위', '해', '▁코와', '이', '어', '를', '▁접', '어', '봤', '어', '용', 'ᄏᄏ']
# [1, 1909, 109, 8, 2682, 16, 849, 100, 954, 63, 739, 95, 2823, 7, 55, 44, 1612, 55, 1214, 55, 142, 531, 2]
# ['▁', '블', '로', '그', '나', '▁리뷰', ',', '길', '거', '리', '를', '▁다', '녀', '도', '▁저렇게', '▁쓰는', '사', '람', '▁굉장', '히', '▁많', '더라구요', 'ᅲᅲ']
# [1, 4, 1463, 24, 508, 41, 429, 0, 297, 56, 94, 44, 30, 1576, 5, 2070, 343, 124, 3969, 1267, 35, 534, 148, 354, 2]
# ['▁잘못된', '▁마스크', '▁쓰는', '법', '이에요']
# [1, 2738, 12, 343, 3096, 241, 2]
# ['▁코', '▁접히', '는', '▁부분', '은', '▁', '최', '대', '한', '▁콧등', '에', '▁붙', '혀', '서', '▁쓰', '세요', 'ᅲᅲ']
# [1, 167, 3161, 6, 391, 8, 4, 3957, 268, 40, 2063, 13, 1010, 1347, 11, 384, 919, 354, 2]
# ['▁저렇게', '▁쓰면', '▁마스크가', '▁', '뭔', '▁소', '용', '인', '가', '용', '?']
# [1, 2070, 189, 82, 4, 3945, 637, 142, 57, 9, 142, 0, 2]
# ['▁콧등', '에', '▁붙', '히', '고', '▁볼부분', '이', '▁밀착이', '▁안되', '면', '▁마스크가', '▁큰거', '라고', '▁생각', '합니당']
# [1, 2063, 13, 1010, 35, 10, 2682, 7, 1286, 943, 42, 82, 1425, 273, 312, 1789, 2]
# ['▁아무', '튼', '▁중형인데', '도', '▁커서', '▁넘', '▁아쉽지만', '....', 'ᅲ']
# [1, 451, 1190, 597, 5, 120, 83, 1522, 0, 275, 2]
# ['▁끈을', '▁묶어', '쓰면', '▁괜찮아서', '▁귀찮', '지만', '▁묶어서', '▁써야', '겠', '네용']
# [1, 510, 1444, 758, 1407, 2687, 33, 453, 870, 811, 1234, 2]
# ['▁색상이', '나', '▁', '촉', '감', '은', '▁넘', '▁좋아요']
# [1, 204, 41, 4, 3880, 329, 8, 83, 37, 2]
# ['▁얼굴', '▁닿는', '▁안감', '도', '▁부', '들', '부', '들', '~~']
# [1, 29, 756, 696, 5, 654, 73, 599, 73, 0, 2]
# ['▁공', '장', '냄', '새', '(?)', '도', '▁', '안나고', '▁마스크', '▁자체', '▁디자인', '도', '▁넘', '▁예뻐요', '!!!']
# [1, 1388, 210, 1880, 1677, 0, 5, 4, 2529, 12, 1009, 230, 5, 83, 154, 0, 2]
# ['▁지금', '▁이', '▁중형보다', '▁조금', '▁작은', '▁사이즈가', '▁나왔으면', '▁하는', '▁바', '램', '...!!!']
# [1, 283, 70, 1689, 52, 97, 104, 2002, 520, 414, 3585, 0, 2]

# %%
import time

print("시작 :     ", time.time())
time.sleep(10)
print("10초 후 출력:", time.time())
# Out:
# 시작 :      1762407872.903229
# 10초 후 출력: 1762407882.9107184

# %%
t = time.localtime()
print(t.tm_year,)
