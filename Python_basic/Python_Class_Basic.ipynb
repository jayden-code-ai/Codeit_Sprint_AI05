# %%
class Dog:  # 🐶 클래스 선언 — 강아지라는 설계도를 만들어요
    def __init__(self, name, age):  
        """객체가 만들어질 때 자동 실행되는 함수"""
        self.name = name  # 🏷️ 인스턴스 변수: 강아지 이름 저장
        self.age = age    # 🕒 인스턴스 변수: 강아지 나이 저장

    def bark(self):  
        """짖는 기능"""
        print(f"{self.name}가 멍멍! 🐾")

# 🧱 실제 객체 만들기
dog1 = Dog("콩이", 3)
dog2 = Dog("보리", 5)

# 🧩 기능 사용
dog1.bark()  # 👉 출력: 콩이가 멍멍! 🐾
print(dog2.age)  # 👉 출력: 5
# Out:
# 콩이가 멍멍! 🐾
# 5

# %%
import matplotlib.font_manager as fm, matplotlib as mpl
font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"
fm.fontManager.addfont(font_path)
mpl.rcParams["font.family"] = "NanumGothic"
mpl.rcParams["axes.unicode_minus"] = False
print("Matplotlib 한글 폰트 설정 완료")
# Out:
# Matplotlib 한글 폰트 설정 완료

# %%
from huggingface_hub import login

# 위젯 대신 login 함수 안에 토큰을 직접 넣어서 로그인합니다.
# "hf_..." 부분에 복사해둔 토큰을 따옴표 안에 넣어주세요.
login(token="hf_...")

# 만약 모델을 업로드(저장)까지 해야 한다면 아래처럼 옵션을 추가할 수 있습니다.
# login(token="hf_...", write_permission=True)
